# %% [markdown]
# # Utilization

# %%
import numpy as np
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
import copy
import sys
sys.path.insert(0, "../src/")
from FwdNeuron import *
from DeepEligNeuron import *
from Network import *
from inputFuc import *
from utils import *
from plotting import *

# %% [markdown]
# # Compare learning

# %% [markdown]
# ## Teacher-student in Multi-layer

# %%
#### With P learning ###
dt = 0.2 #ms

init_phase = 300 #ms
init_phase_steps = int(init_phase/dt) 
learn_phase = 12000 # ms
learn_phase_steps = int(learn_phase/dt) 
eval_phase = 200 # ms
eval_phase_steps = int(eval_phase/dt)

# init both teacher and student net
n_in, n_hidden1, n_hidden2, n_out = 4, 3, 2, 2
beta=0.05
activation='sigmoid'

student = DENetwork(
    layers=[
        FwdDENeurons(n_in=n_in, n_neurons=n_hidden1, tau=[1.7, 3., 7.], lr_w=1.0,
                     activation=activation, dt=dt, scale=0.6),
        LastFwdDENeurons(n_in=n_hidden1, n_neurons=n_hidden2, tau=[8, 17], lr_w=0.2,
                     activation=activation, dt=dt, scale=1.6),
        FwdNeurons(n_in=n_hidden2, n_neurons=n_out, tau=dt, 
                   lr_w=0.0, activation='linear', dt=dt, beta=beta)
    ],)

# n_in, n_hidden1, n_out = 3, 2, 1
# student = FwdNetwork(
#     layers=[
#         FwdEPNeurons(n_in=n_in, n_neurons=n_hidden1, tau=[13, 67], lr_w=1.5,
#                      activation=activation, dt=dt, scale=1.6),
#         FwdNeurons(n_in=n_hidden1, n_neurons=n_out, tau=dt, 
#                    lr_w=0.0, activation='linear', dt=dt, beta=beta)
#     ],)


student2 = FwdNetwork(net=student, layers=FwdEPNeurons)

student3 = FwdNetwork(net=student, layers=FwdGLENeurons)
student_naive = copy.deepcopy(student2)
teacher = copy.deepcopy(student2)

Students={'DeepElig':student, 'Eprop':student2, 'GLE':student3, 'naive':student_naive}



# deviate teacher by small perturbation
for i, l in enumerate(student.layers[:-1]):
    deviate = torch.randn(l.W_in.shape)*6e-1
    teacher.layers[i].W_in += deviate
# deviate = torch.randn(teacher.layers[-1].W_in.shape)*1e-2
# teacher.layers[-1].W_in += deviate

input_fuc = mul_sin_function(n=n_in, n_sin=2, period=(20, 80), bias = (-0.5, 0.5), magnitude=(0.2, 1), phase = (0, 6), dt=dt)
#input_fuc = mul_sin_function(n=n_in, n_sin=2, period=(15, 40), bias=(-0.1, 0.1), magnitude=(0.2, 1.0), phase=(0, 6), dt=dt)
#input_fuc = low_pass_OU(size=n_in, lp_tau=(0.5, 2), tau=(10, 25), mu=(-0.2, 0.2), sigma=(0.1, 0.5), dt = dt)


#recorders
Rcd = Recorder(['input', 'teacher', 'student'])

with torch.no_grad():
    
    for t in range(init_phase_steps):
        inp = input_fuc(t)
        r_out_target, u_out_target = teacher.step(inp)
        r_out, u_out = student.step(inp)
        r_out1, u_out = student3.step(inp)
        if (r_out != r_out1).any():
            print(r_out, r_out1)
        error = u_out_target - u_out
        student.prop(error)
        student2.prop(error)
        Rcd.rec([inp, u_out_target, u_out])
        
    print("reach steady state with error: %f"%(error**2).mean().item())

Rcd.finish()

fig, axs = plt.subplots(2, 1, figsize=(10, 8), sharex=True)
x = np.arange(0, init_phase, dt)
axs[0].plot(x, Rcd['input'].mean(axis=0), color='r', linewidth=2)
for i in range(n_in):
    axs[0].plot(x, Rcd['input'][i][0:], alpha = 0.3)
for i in range(n_out):
    axs[1].plot(x, Rcd['teacher'][i][0:], label="teacher", color = black)
    axs[1].plot(x, Rcd['student'][i][0:], label="student", color = lightblue)
axs[1].legend()
axs[1].set_xlabel("t (ms)")
axs[0].set_ylabel(r"$r_{in}$")
axs[1].set_ylabel(r"$r_o$")

plt.show()
# Out:
# reach steady state with error: 0.095459

# %%
Cum_errors = 3*[(error**2).mean().item()]
error_record, mismatch_record = [], []
cum_eps = 0
Students['Eprop'].align(student)
Students['GLE'].align(student)
Rcd = Recorder(['dt_tau_de', 'rhod'])

with torch.no_grad():
    for t in range(learn_phase_steps):
        t += init_phase_steps
        inp = input_fuc(t)
        r_out_target, u_out_target = teacher.step(inp)
        
        for i, stu in enumerate(['DeepElig', 'Eprop', 'GLE']):
            r_out, u_out = Students[stu].step(inp)
            error = u_out_target - u_out
            Students[stu].prop(error)
            Students[stu].learnW()
            Cum_errors[i] = 0.999*Cum_errors[i] + 0.001*(error**2).mean().item()
        
        if (t*dt)%100==0:
            error_record.append(list(Cum_errors))
            
            print("target: ", u_out_target.mean().numpy(), "output: ", u_out.mean().numpy(), 
                  " error: %5e, t: %d ms"%(Cum_errors[0], t*dt))
#Rcd.finish()
# Out:
# target:  0.4308834 output:  0.5103282  error: 9.546077e-02, t: 300 ms
# target:  0.42622373 output:  0.49427807  error: 7.434443e-02, t: 400 ms
# target:  0.40875095 output:  0.48125386  error: 5.108615e-02, t: 500 ms
# target:  0.4392761 output:  0.5120256  error: 3.713337e-02, t: 600 ms
# target:  0.43437272 output:  0.49708065  error: 2.601379e-02, t: 700 ms
# target:  0.4062082 output:  0.49229196  error: 1.922474e-02, t: 800 ms
# target:  0.43707484 output:  0.5173714  error: 1.558087e-02, t: 900 ms
# target:  0.43248177 output:  0.5220249  error: 1.389195e-02, t: 1000 ms
# target:  0.38693747 output:  0.47222948  error: 1.113160e-02, t: 1100 ms
# target:  0.43881333 output:  0.5261189  error: 1.029950e-02, t: 1200 ms
# target:  0.42123574 output:  0.49262238  error: 8.859063e-03, t: 1300 ms
# target:  0.4049734 output:  0.4852754  error: 7.940905e-03, t: 1400 ms
# target:  0.41038257 output:  0.47210157  error: 7.268901e-03, t: 1500 ms
# target:  0.434216 output:  0.48066384  error: 5.995576e-03, t: 1600 ms
# target:  0.4315961 output:  0.47574383  error: 5.174868e-03, t: 1700 ms
# target:  0.40037155 output:  0.4290568  error: 5.013685e-03, t: 1800 ms
# target:  0.44359168 output:  0.48867187  error: 4.495361e-03, t: 1900 ms
# target:  0.44056988 output:  0.46526477  error: 4.421548e-03, t: 2000 ms
# target:  0.39397013 output:  0.44455707  error: 3.835544e-03, t: 2100 ms
# target:  0.4390209 output:  0.47182563  error: 4.157739e-03, t: 2200 ms
# target:  0.43396646 output:  0.479926  error: 3.617645e-03, t: 2300 ms
# target:  0.4122756 output:  0.4469222  error: 3.117703e-03, t: 2400 ms
# target:  0.43652534 output:  0.4809515  error: 2.759324e-03, t: 2500 ms
# target:  0.43521112 output:  0.4662694  error: 2.626422e-03, t: 2600 ms
# target:  0.42199445 output:  0.44920823  error: 2.424793e-03, t: 2700 ms
# target:  0.42302752 output:  0.445452  error: 2.150899e-03, t: 2800 ms
# target:  0.4393471 output:  0.44829026  error: 2.385238e-03, t: 2900 ms
# target:  0.43487045 output:  0.44289014  error: 2.142223e-03, t: 3000 ms
# target:  0.40504932 output:  0.4077555  error: 2.308414e-03, t: 3100 ms
# target:  0.443947 output:  0.44722536  error: 2.474390e-03, t: 3200 ms
# target:  0.4412429 output:  0.4439416  error: 2.575273e-03, t: 3300 ms
# target:  0.3999782 output:  0.41134062  error: 2.400286e-03, t: 3400 ms
# target:  0.44472337 output:  0.45465526  error: 2.217465e-03, t: 3500 ms
# target:  0.44247282 output:  0.44359446  error: 1.895734e-03, t: 3600 ms
# target:  0.41143838 output:  0.42881322  error: 1.612153e-03, t: 3700 ms
# target:  0.42216396 output:  0.43030888  error: 1.519524e-03, t: 3800 ms
# target:  0.43357646 output:  0.4479571  error: 1.291075e-03, t: 3900 ms
# target:  0.41846377 output:  0.42199317  error: 1.154897e-03, t: 4000 ms
# target:  0.40915132 output:  0.41627738  error: 1.043060e-03, t: 4100 ms
# target:  0.4200257 output:  0.42553478  error: 9.714737e-04, t: 4200 ms
# target:  0.4324811 output:  0.42040733  error: 1.035967e-03, t: 4300 ms
# target:  0.39819828 output:  0.3980742  error: 1.113185e-03, t: 4400 ms
# target:  0.43162498 output:  0.42056  error: 1.357752e-03, t: 4500 ms
# target:  0.4363763 output:  0.4348764  error: 1.439688e-03, t: 4600 ms
# target:  0.3993483 output:  0.39335403  error: 1.429807e-03, t: 4700 ms
# target:  0.4380846 output:  0.44894648  error: 1.446609e-03, t: 4800 ms
# target:  0.43786564 output:  0.43183982  error: 1.452141e-03, t: 4900 ms
# target:  0.40901336 output:  0.42922068  error: 1.190041e-03, t: 5000 ms
# target:  0.414031 output:  0.4174943  error: 1.300257e-03, t: 5100 ms
# target:  0.4343418 output:  0.4471522  error: 1.170640e-03, t: 5200 ms
# target:  0.4227609 output:  0.43164712  error: 1.014630e-03, t: 5300 ms
# target:  0.39928758 output:  0.4066766  error: 9.175865e-04, t: 5400 ms
# target:  0.4200448 output:  0.4314453  error: 9.150953e-04, t: 5500 ms
# target:  0.43865174 output:  0.42617506  error: 9.372112e-04, t: 5600 ms
# target:  0.3989456 output:  0.4037668  error: 1.014717e-03, t: 5700 ms
# target:  0.42499182 output:  0.4206342  error: 8.864155e-04, t: 5800 ms
# target:  0.4464337 output:  0.44314414  error: 8.911413e-04, t: 5900 ms
# target:  0.4029837 output:  0.39490044  error: 8.629854e-04, t: 6000 ms
# target:  0.4395556 output:  0.44389856  error: 1.002522e-03, t: 6100 ms
# target:  0.44127873 output:  0.44306475  error: 9.189456e-04, t: 6200 ms
# target:  0.41290414 output:  0.42063212  error: 9.556558e-04, t: 6300 ms
# target:  0.42629936 output:  0.43603694  error: 1.030192e-03, t: 6400 ms
# target:  0.4266334 output:  0.4355732  error: 9.446019e-04, t: 6500 ms
# target:  0.42842895 output:  0.44341642  error: 1.045400e-03, t: 6600 ms
# target:  0.38648134 output:  0.39175618  error: 9.499259e-04, t: 6700 ms
# target:  0.42116913 output:  0.4361347  error: 9.656311e-04, t: 6800 ms
# target:  0.4385496 output:  0.43914106  error: 8.728235e-04, t: 6900 ms
# target:  0.39478943 output:  0.3914173  error: 8.069368e-04, t: 7000 ms
# target:  0.42159432 output:  0.4314155  error: 8.773222e-04, t: 7100 ms
# target:  0.44467226 output:  0.43352786  error: 6.857163e-04, t: 7200 ms
# target:  0.40968618 output:  0.4134734  error: 5.981679e-04, t: 7300 ms
# target:  0.41767865 output:  0.4152378  error: 6.346693e-04, t: 7400 ms
# target:  0.43663195 output:  0.44823912  error: 6.674933e-04, t: 7500 ms
# target:  0.41560945 output:  0.41376984  error: 7.132738e-04, t: 7600 ms
# target:  0.41776255 output:  0.43325502  error: 7.613730e-04, t: 7700 ms
# target:  0.41796112 output:  0.42660022  error: 8.764487e-04, t: 7800 ms
# target:  0.42936713 output:  0.44132173  error: 8.526931e-04, t: 7900 ms
# target:  0.40199307 output:  0.40542772  error: 8.241302e-04, t: 8000 ms
# target:  0.42049032 output:  0.4309863  error: 7.594484e-04, t: 8100 ms
# target:  0.44753277 output:  0.45503947  error: 7.584738e-04, t: 8200 ms
# target:  0.39998505 output:  0.39076793  error: 6.711320e-04, t: 8300 ms
# target:  0.4347192 output:  0.441481  error: 5.762320e-04, t: 8400 ms
# target:  0.45134127 output:  0.43931684  error: 6.085633e-04, t: 8500 ms
# target:  0.4051229 output:  0.4077043  error: 4.990732e-04, t: 8600 ms
# target:  0.42748487 output:  0.4205234  error: 6.211193e-04, t: 8700 ms
# target:  0.43623307 output:  0.43375266  error: 5.669509e-04, t: 8800 ms
# target:  0.43500042 output:  0.43027088  error: 6.208358e-04, t: 8900 ms
# target:  0.41243255 output:  0.4117937  error: 6.944539e-04, t: 9000 ms
# target:  0.43219346 output:  0.43339905  error: 6.417795e-04, t: 9100 ms
# target:  0.44927755 output:  0.44667268  error: 6.090512e-04, t: 9200 ms
# target:  0.41387397 output:  0.4123066  error: 5.631524e-04, t: 9300 ms
# target:  0.42370766 output:  0.42633027  error: 5.143534e-04, t: 9400 ms
# target:  0.45376956 output:  0.4505782  error: 5.053983e-04, t: 9500 ms
# target:  0.40831915 output:  0.39801484  error: 4.397449e-04, t: 9600 ms
# target:  0.42916423 output:  0.42355263  error: 5.778548e-04, t: 9700 ms
# target:  0.4448893 output:  0.43372923  error: 5.832686e-04, t: 9800 ms
# target:  0.41265452 output:  0.4054127  error: 5.343721e-04, t: 9900 ms
# target:  0.42037007 output:  0.41292292  error: 6.478082e-04, t: 10000 ms
# target:  0.4366336 output:  0.42621607  error: 6.300346e-04, t: 10100 ms
# target:  0.42776754 output:  0.42587858  error: 5.023037e-04, t: 10200 ms
# target:  0.4097663 output:  0.405198  error: 5.766305e-04, t: 10300 ms
# target:  0.42492524 output:  0.42818758  error: 5.068573e-04, t: 10400 ms
# target:  0.4475273 output:  0.442126  error: 4.504742e-04, t: 10500 ms
# target:  0.40445825 output:  0.40156105  error: 3.723959e-04, t: 10600 ms
# target:  0.40726244 output:  0.41360646  error: 3.925737e-04, t: 10700 ms
# target:  0.44575024 output:  0.43915617  error: 3.721984e-04, t: 10800 ms
# target:  0.40459445 output:  0.40169224  error: 3.717544e-04, t: 10900 ms
# target:  0.4115578 output:  0.4080097  error: 4.268995e-04, t: 11000 ms
# target:  0.43670893 output:  0.4351919  error: 5.161569e-04, t: 11100 ms
# target:  0.40974116 output:  0.3984317  error: 5.208074e-04, t: 11200 ms
# target:  0.4151193 output:  0.41590494  error: 5.020257e-04, t: 11300 ms
# target:  0.42501512 output:  0.41704708  error: 5.450962e-04, t: 11400 ms
# target:  0.4318065 output:  0.43632105  error: 4.512830e-04, t: 11500 ms
# target:  0.4136242 output:  0.4079965  error: 4.039672e-04, t: 11600 ms
# target:  0.4247713 output:  0.42970192  error: 3.782512e-04, t: 11700 ms
# target:  0.45197433 output:  0.4514619  error: 3.482196e-04, t: 11800 ms
# target:  0.40329134 output:  0.39917648  error: 3.375299e-04, t: 11900 ms
# target:  0.4134665 output:  0.42175716  error: 3.638662e-04, t: 12000 ms
# target:  0.44805783 output:  0.4423595  error: 3.506837e-04, t: 12100 ms
# target:  0.40755475 output:  0.4066609  error: 4.544613e-04, t: 12200 ms

# %%
Error_record = np.array(error_record).T
fig = plt.figure(figsize=(10, 4))
time = np.arange(Error_record.shape[1])*100
ax = fig.add_subplot(111)
ax2 = ax.twinx()
ax.set_yscale('log')
ax.set_ylabel('loss', rotation=0)
ax2.set_yscale('log')
#ax2.set_ylabel(r"$\mathbf{u}^{ɑ}$", rotation=0)
l1,  = ax.plot(time, Error_record[0], label="DeepE", color=blue, linewidth=2.8, alpha=0.8)
l11, = ax.plot(time, Error_record[1], label="E-prop", color=green, linewidth=2., alpha=0.8)
l12, = ax.plot(time, Error_record[2], label="GLE", color=purple, linewidth=2., alpha=0.8)
lines = [l1, l11, l12]
labels = [line.get_label() for line in lines]
ax.legend(lines, labels, loc='upper right', frameon=False)
ax.set_xlabel('t (ms)')

plt.tight_layout()
#plt.savefig('./fig/losscurvecompare2L.png')
plt.show()

# %%
Rcd_eval = Recorder(['input', 'teacher', 'DeepElig', 'Eprop', 'GLE', 'naive'])
Students['naive'].align(student)
with torch.no_grad():
    for t in range(eval_phase_steps):
        t = t+init_phase_steps+learn_phase_steps
        inp = input_fuc(t)
        Rcd_eval.rec_single('input', inp)
        r_out_target, u_out_target = teacher.step(inp)
        Rcd_eval.rec_single('teacher', u_out_target)
        for k, stu in Students.items():
            r_out, u_out = stu.step(inp)
            Rcd_eval.rec_single(k, u_out)

Rcd_eval.finish()

fig, axs = plt.subplots(2, 1, figsize=(10, 8), sharex=True)
x = np.arange(0, eval_phase, dt)
axs[0].plot(x, Rcd_eval['input'].mean(axis=0), color='r', linewidth=2)
for i in range(n_in):
    axs[0].plot(x, Rcd_eval['input'][i][0:], alpha = 0.3)
for i in range(n_out):
    axs[1].plot(x, Rcd_eval['teacher'][i][0:], label="teacher", color = black, linewidth=1.5, alpha=0.8)
    axs[1].plot(x, Rcd_eval['naive'][i][0:], label="naive", color = lightblue, linewidth=2, alpha=0.8)
    axs[1].plot(x, Rcd_eval['DeepElig'][i][:], label="DeepE", color = blue, linewidth=2.4, alpha=0.8)
    axs[1].plot(x, Rcd_eval['Eprop'][i][:], label="Eprop", color = green, linewidth=2, alpha=0.8)
    axs[1].plot(x, Rcd_eval['GLE'][i][:], label="GLE", color = purple, linewidth=2, alpha=0.8)
axs[1].legend()
axs[1].set_xlabel("t (ms)")

axs[0].set_ylabel(r"$r_{in}$")
axs[1].set_ylabel(r"$r_o$")

for ax in axs:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

plt.tight_layout()
#plt.savefig('./fig/CompareAft2L.png')
plt.show()

plt.show()

# %%
student.layers[2].T
# Out:
# tensor([[ 1.0000,  0.0000, -0.1429, -0.6000, -7.0000],
#         [ 0.0000,  1.0000, -0.0625, -0.2143, -0.7000]])

# %%
Rcd.finish()

# %%
fig, axs = plt.subplots(2, 1, figsize=(10, 8), sharex=True)
tau_de = np.clip(dt/(Rcd['dt_tau_de'][:, 1000:]), -30, 80)
for i in range(n_hidden1):
    axs[0].plot(tau_de[i, 8000:8500], linewidth=2.5)
for i in range(n_hidden2):
    axs[1].plot(Rcd['rhod'][i, 3000:3500], linewidth=2.5)
axs[0].set_ylabel(r"$\tau^*$", rotation=0)
axs[1].set_ylabel(r"$\rho'$", rotation=0)
plt.show()
# Out:
# C:\Users\Bingkun LIU\AppData\Local\Temp\ipykernel_14460\132200789.py:2: RuntimeWarning: divide by zero encountered in divide
#   tau_de = np.clip(dt/(Rcd['dt_tau_de'][:, 1000:]), -30, 80)

# %%
#### With P learning ###
dt = 0.1 #ms

init_phase = 100 #ms
init_phase_steps = int(init_phase/dt) 
learn_phase = 12000 # ms
learn_phase_steps = int(learn_phase/dt) 
eval_phase = 100 # ms
eval_phase_steps = int(eval_phase/dt)

# init both teacher and student net
N, bit_time = 3, 2

n_in, n_hidden1, n_hidden2, n_hidden3, n_out = 1, 8, 4, 4, 2
beta=0.1
activation='sigmoid'

student = DENetwork(
    layers=[
        FwdDENeurons(n_in=n_in, n_neurons=n_hidden1, tau_d = dt*np.logspace(0, 2, n_hidden1, dtype=np.float32), lr_w=1e1,
                     activation=activation, dt=dt),
        FwdDENeurons(n_in=n_hidden1, n_neurons=n_hidden2, tau_d = [2*dt, 0.8, 1.7, 3.5], lr_w=2e0,
                     activation=activation, dt=dt),
        LastNeurons(n_in=n_hidden2, n_neurons=n_hidden3, tau_d = [3*dt, 0.4, 3.7, 7.1], lr_w=0.8,
                     activation=activation, dt=dt),
        OutNeurons(n_in=n_hidden3, n_neurons=n_out, tau_d = dt, 
                   lr_w=0.2, activation='linear', dt=dt, beta=beta)
    ],)
student_naive = copy.deepcopy(student)

student2 = SequentialNetwork(net=student, layers=FwdEPNeurons)

student3 = SequentialNetwork(net=student, layers=FwdGLENeurons)

Students={'DeepElig':student, 'Eprop':student2, 'GLE':student3, 'naive':student_naive}

input_fuc = StepParity(N=N, bit_time=bit_time, dt=dt)

#recorders
Rcd = Recorder(['input', 'teacher', 'student', 'mismatch'])

with torch.no_grad():
    
    for t in range(init_phase_steps):
        input, label = input_fuc()
        r_out, u_out = student.step(input)
        Rcd.rec([input, label, u_out, student.mismatch(0)])
        
    error = label - torch.sigmoid(u_out)
    print("reach steady state with error: %f"%(error**2).mean().item())

Rcd.finish()

fig, axs = plt.subplots(3, 1, figsize=(10, 10), sharex=True)
x = np.arange(0, init_phase, dt)
axs[0].plot(x, Rcd['input'].mean(axis=0)*0.6, color=black, label='input', linewidth=2, alpha=0.8)
axs[0].plot(x, 0.5*(Rcd['teacher'][1]-Rcd['teacher'][0]), label="Parity", color = red, alpha=0.8, linewidth=3)
for i in range(n_out):
    axs[i+1].plot(x, Rcd['student'][i], label="student %d"%i, color = lightblue)


axs[-1].set_xlabel("t (ms)")
axs[0].set_ylabel(r"$r_{in}$")
axs[0].legend()
axs[1].set_ylabel(r"$r_o$")

plt.show()
# Out:
# reach steady state with error: 0.315749

# %%
Cum_errors = np.array(4*[(error**2).mean().item()])
error_record, mismatch_record = [], []
cum_eps = 0
Students['Eprop'].align(student)
Students['GLE'].align(student)
Rcd = Recorder(['input', 'mismatch', 'rhod'])

with torch.no_grad():
    for t in range(learn_phase_steps):
        t += init_phase_steps
        input, label = input_fuc()
        
        for i, stu in enumerate(['DeepElig', 'Eprop', 'GLE']):
            r_out, u_out = Students[stu].step(input)
            error = (label - torch.sigmoid(u_out))
            Students[stu].learnP(error)
            Students[stu].learnW()
            Cum_errors[i] = 0.999*Cum_errors[i] + 0.001*(error**2).mean().item()

        # Rcd.rec([input, student.mismatch(0), student.mismatch(-1), student.epsilon(1), 
        #          student.layers[0].rho.d, student3.mismatch(0)])
        cum_eps = 0.99*cum_eps + 0.01*(Students['DeepElig'].mismatch(0).abs()).mean().item()

        if (t*dt)%100==0:
            mismatch_record.append(cum_eps)
            error_record.append(list(Cum_errors))
            
            # for i, stu in enumerate(['DeepElig', 'Eprop', 'GLE']):
            #     Students[stu].layers[-1].beta *= 0.95
            
            print(" mismatch: %5e, error: %5e, t: %d ms"%(mismatch_record[-1], Cum_errors[0], t*dt))

Rcd.finish()
error_record = np.array(error_record).T
# Out:
#  mismatch: 0.000000e+00, error: 3.157496e-01, t: 100 ms
#  mismatch: 0.000000e+00, error: 2.777105e-01, t: 200 ms
#  mismatch: 0.000000e+00, error: 2.568120e-01, t: 300 ms
#  mismatch: 0.000000e+00, error: 2.561322e-01, t: 400 ms
#  mismatch: 0.000000e+00, error: 2.533742e-01, t: 500 ms
#  mismatch: 0.000000e+00, error: 2.501291e-01, t: 600 ms
#  mismatch: 0.000000e+00, error: 2.527005e-01, t: 700 ms
#  mismatch: 0.000000e+00, error: 2.434115e-01, t: 800 ms
#  mismatch: 0.000000e+00, error: 2.501893e-01, t: 900 ms
#  mismatch: 0.000000e+00, error: 2.531132e-01, t: 1000 ms
#  mismatch: 0.000000e+00, error: 2.519582e-01, t: 1100 ms
#  mismatch: 0.000000e+00, error: 2.403008e-01, t: 1200 ms
#  mismatch: 0.000000e+00, error: 2.492268e-01, t: 1300 ms
#  mismatch: 0.000000e+00, error: 2.492297e-01, t: 1400 ms
#  mismatch: 0.000000e+00, error: 2.473740e-01, t: 1500 ms
#  mismatch: 0.000000e+00, error: 2.507880e-01, t: 1600 ms
#  mismatch: 0.000000e+00, error: 2.518807e-01, t: 1700 ms
#  mismatch: 0.000000e+00, error: 2.498332e-01, t: 1800 ms
#  mismatch: 0.000000e+00, error: 2.507896e-01, t: 1900 ms
#  mismatch: 0.000000e+00, error: 2.431441e-01, t: 2000 ms
#  mismatch: 0.000000e+00, error: 2.357082e-01, t: 2100 ms
#  mismatch: 0.000000e+00, error: 2.476238e-01, t: 2200 ms
#  mismatch: 0.000000e+00, error: 2.506235e-01, t: 2300 ms
#  mismatch: 0.000000e+00, error: 2.425612e-01, t: 2400 ms
#  mismatch: 0.000000e+00, error: 2.501783e-01, t: 2500 ms
#  mismatch: 0.000000e+00, error: 2.495009e-01, t: 2600 ms
#  mismatch: 0.000000e+00, error: 2.507693e-01, t: 2700 ms
#  mismatch: 0.000000e+00, error: 2.507722e-01, t: 2800 ms
#  mismatch: 0.000000e+00, error: 2.517884e-01, t: 2900 ms
#  mismatch: 0.000000e+00, error: 2.413459e-01, t: 3000 ms
#  mismatch: 0.000000e+00, error: 2.406772e-01, t: 3100 ms
#  mismatch: 0.000000e+00, error: 2.525571e-01, t: 3200 ms
#  mismatch: 0.000000e+00, error: 2.519561e-01, t: 3300 ms
#  mismatch: 0.000000e+00, error: 2.514781e-01, t: 3400 ms
#  mismatch: 0.000000e+00, error: 2.477490e-01, t: 3500 ms
#  mismatch: 0.000000e+00, error: 2.479942e-01, t: 3600 ms
#  mismatch: 0.000000e+00, error: 2.512666e-01, t: 3700 ms
#  mismatch: 0.000000e+00, error: 2.511515e-01, t: 3800 ms
#  mismatch: 0.000000e+00, error: 2.461555e-01, t: 3900 ms
#  mismatch: 0.000000e+00, error: 2.410094e-01, t: 4000 ms
#  mismatch: 0.000000e+00, error: 2.496637e-01, t: 4100 ms
#  mismatch: 0.000000e+00, error: 2.455800e-01, t: 4200 ms
#  mismatch: 0.000000e+00, error: 2.485125e-01, t: 4300 ms
#  mismatch: 0.000000e+00, error: 2.484654e-01, t: 4400 ms
#  mismatch: 0.000000e+00, error: 2.360968e-01, t: 4500 ms
#  mismatch: 0.000000e+00, error: 2.468210e-01, t: 4600 ms
#  mismatch: 0.000000e+00, error: 2.523034e-01, t: 4700 ms
#  mismatch: 0.000000e+00, error: 2.482323e-01, t: 4800 ms
#  mismatch: 0.000000e+00, error: 2.476011e-01, t: 4900 ms
#  mismatch: 0.000000e+00, error: 2.515353e-01, t: 5000 ms
#  mismatch: 0.000000e+00, error: 2.443287e-01, t: 5100 ms
#  mismatch: 0.000000e+00, error: 2.521765e-01, t: 5200 ms
#  mismatch: 0.000000e+00, error: 2.515906e-01, t: 5300 ms
#  mismatch: 0.000000e+00, error: 2.507245e-01, t: 5400 ms
#  mismatch: 0.000000e+00, error: 2.506725e-01, t: 5500 ms
#  mismatch: 0.000000e+00, error: 2.500116e-01, t: 5600 ms
#  mismatch: 0.000000e+00, error: 2.502647e-01, t: 5700 ms
#  mismatch: 0.000000e+00, error: 2.488653e-01, t: 5800 ms
#  mismatch: 0.000000e+00, error: 2.510874e-01, t: 5900 ms
#  mismatch: 0.000000e+00, error: 2.503372e-01, t: 6000 ms
#  mismatch: 0.000000e+00, error: 2.400170e-01, t: 6100 ms
#  mismatch: 0.000000e+00, error: 2.482415e-01, t: 6200 ms
#  mismatch: 0.000000e+00, error: 2.504655e-01, t: 6300 ms
#  mismatch: 0.000000e+00, error: 2.510429e-01, t: 6400 ms
#  mismatch: 0.000000e+00, error: 2.498943e-01, t: 6500 ms
#  mismatch: 0.000000e+00, error: 2.465860e-01, t: 6600 ms
#  mismatch: 0.000000e+00, error: 2.471307e-01, t: 6700 ms
#  mismatch: 0.000000e+00, error: 2.491905e-01, t: 6800 ms
#  mismatch: 0.000000e+00, error: 2.488497e-01, t: 6900 ms
#  mismatch: 0.000000e+00, error: 2.484192e-01, t: 7000 ms
#  mismatch: 0.000000e+00, error: 2.449473e-01, t: 7100 ms
#  mismatch: 0.000000e+00, error: 2.462763e-01, t: 7200 ms
#  mismatch: 0.000000e+00, error: 2.433481e-01, t: 7300 ms
#  mismatch: 0.000000e+00, error: 2.482490e-01, t: 7400 ms
#  mismatch: 0.000000e+00, error: 2.470004e-01, t: 7500 ms
#  mismatch: 0.000000e+00, error: 2.455012e-01, t: 7600 ms
#  mismatch: 0.000000e+00, error: 2.484617e-01, t: 7700 ms
#  mismatch: 0.000000e+00, error: 2.443502e-01, t: 7800 ms
#  mismatch: 0.000000e+00, error: 2.474660e-01, t: 7900 ms
#  mismatch: 0.000000e+00, error: 2.501116e-01, t: 8000 ms
#  mismatch: 0.000000e+00, error: 2.485351e-01, t: 8100 ms
#  mismatch: 0.000000e+00, error: 2.494900e-01, t: 8200 ms
#  mismatch: 0.000000e+00, error: 2.418470e-01, t: 8300 ms
#  mismatch: 0.000000e+00, error: 2.489338e-01, t: 8400 ms
#  mismatch: 0.000000e+00, error: 2.497362e-01, t: 8500 ms
#  mismatch: 0.000000e+00, error: 2.502391e-01, t: 8600 ms
#  mismatch: 0.000000e+00, error: 2.507361e-01, t: 8700 ms
#  mismatch: 0.000000e+00, error: 2.503798e-01, t: 8800 ms
#  mismatch: 0.000000e+00, error: 2.504456e-01, t: 8900 ms
#  mismatch: 0.000000e+00, error: 2.504268e-01, t: 9000 ms
#  mismatch: 0.000000e+00, error: 2.435504e-01, t: 9100 ms
#  mismatch: 0.000000e+00, error: 2.405992e-01, t: 9200 ms
#  mismatch: 0.000000e+00, error: 2.499768e-01, t: 9300 ms
#  mismatch: 0.000000e+00, error: 2.414574e-01, t: 9400 ms
#  mismatch: 0.000000e+00, error: 2.352150e-01, t: 9500 ms
#  mismatch: 0.000000e+00, error: 2.459253e-01, t: 9600 ms
#  mismatch: 0.000000e+00, error: 2.486730e-01, t: 9700 ms
#  mismatch: 0.000000e+00, error: 2.496407e-01, t: 9800 ms
#  mismatch: 0.000000e+00, error: 2.485968e-01, t: 9900 ms
#  mismatch: 0.000000e+00, error: 2.489045e-01, t: 10000 ms
#  mismatch: 0.000000e+00, error: 2.486384e-01, t: 10100 ms
#  mismatch: 0.000000e+00, error: 2.485674e-01, t: 10200 ms
#  mismatch: 0.000000e+00, error: 2.506572e-01, t: 10300 ms
#  mismatch: 0.000000e+00, error: 2.503084e-01, t: 10400 ms
#  mismatch: 0.000000e+00, error: 2.403827e-01, t: 10500 ms
#  mismatch: 0.000000e+00, error: 2.502641e-01, t: 10600 ms
#  mismatch: 0.000000e+00, error: 2.477889e-01, t: 10700 ms
#  mismatch: 0.000000e+00, error: 2.456878e-01, t: 10800 ms
#  mismatch: 0.000000e+00, error: 2.467253e-01, t: 10900 ms
#  mismatch: 0.000000e+00, error: 2.492102e-01, t: 11000 ms
#  mismatch: 0.000000e+00, error: 2.502397e-01, t: 11100 ms
#  mismatch: 0.000000e+00, error: 2.496824e-01, t: 11200 ms
#  mismatch: 0.000000e+00, error: 2.505227e-01, t: 11300 ms
#  mismatch: 0.000000e+00, error: 2.503325e-01, t: 11400 ms
#  mismatch: 0.000000e+00, error: 2.374597e-01, t: 11500 ms
#  mismatch: 0.000000e+00, error: 2.490539e-01, t: 11600 ms
#  mismatch: 0.000000e+00, error: 2.494794e-01, t: 11700 ms
#  mismatch: 0.000000e+00, error: 2.466995e-01, t: 11800 ms
#  mismatch: 0.000000e+00, error: 2.502593e-01, t: 11900 ms
#  mismatch: 0.000000e+00, error: 2.486804e-01, t: 12000 ms

# %%
Error_record = np.array(error_record)#.T
fig = plt.figure(figsize=(10, 4))
time = np.arange(Error_record.shape[1])*100
ax = fig.add_subplot(111)
ax2 = ax.twinx()
ax.set_yscale('log')
ax.set_ylabel('loss', rotation=0)
ax2.set_yscale('log')
#ax2.set_ylabel(r"$\mathbf{u}^{ɑ}$", rotation=0)
l1,  = ax.plot(time, Error_record[0], label="DeepE", color=blue, linewidth=2.5, alpha=0.8)
l11, = ax.plot(time, Error_record[1], label="E-prop", color=green, linewidth=2.5, alpha=0.8)
l12, = ax.plot(time, Error_record[2], label="GLE", color=purple, linewidth=2.5, alpha=0.8)
lines = [l1, l11, l12]
labels = [line.get_label() for line in lines]
ax.legend(lines, labels, loc='upper right', frameon=False)
ax.set_xlabel('t (ms)')

plt.tight_layout()
#plt.savefig('./fig/losscurvecompare2L.png')
plt.show()

# %%
Rcd_eval = Recorder(['input', 'teacher', 'DeepElig', 'Eprop', 'GLE', 'naive'])

#Students['naive'].align(student)
with torch.no_grad():
    for t in range(eval_phase_steps):
        t = t+init_phase_steps+learn_phase_steps
        input, label = input_fuc()
        Rcd_eval.rec_single('input', input)
        Rcd_eval.rec_single('teacher', label)
        for k, stu in Students.items():
            r_out, u_out = stu.step(input)
            Rcd_eval.rec_single(k, u_out)

Rcd_eval.finish()



fig, axs = plt.subplots(4, 1, figsize=(10, 10), sharex=True)
x = np.arange(0, eval_phase, dt)
axs[0].plot(x, Rcd_eval['input'].mean(axis=0), color=black, label='input', linewidth=2, alpha=0.8)

axs[1].plot(x, 0.5*(Rcd_eval['teacher'][1]-Rcd_eval['teacher'][0])+0.5, label="Parity", color=darkred, alpha=0.3, linewidth=4)
for stu, clr in zip(['DeepElig', 'Eprop', 'GLE'], [blue, green, purple, pink, lightblue]):
    prediction = np.exp(Rcd_eval[stu])
    prediction = prediction[1]/(prediction.sum(axis=0))
    axs[1].plot(x, prediction, label=stu, alpha=0.8, linewidth=2, color=clr)
    
for i in range(n_out):
    axs[i+2].plot(x, Rcd_eval['naive'][i][:], label="naive", color = lightblue, linewidth=2)
    axs[i+2].plot(x, Rcd_eval['DeepElig'][i][:], label="DeepElig", color = blue, linewidth=2)
    axs[i+2].plot(x, Rcd_eval['Eprop'][i][:], label="Eprop", color = green, linewidth=2)
    axs[i+2].plot(x, Rcd_eval['GLE'][i][:], label="GLE", color = purple, linewidth=2)
    
axs[0].legend()
axs[1].legend()
axs[2].legend()
axs[-1].set_xlabel("t (ms)")

axs[0].set_ylabel(r"$r_{in}$")
axs[1].set_ylabel(r"$r_{even}$")
axs[2].set_ylabel(r"$r_{odd}$")

for ax in axs:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

plt.tight_layout()
#plt.savefig('./fig/CompareAftRec.png')
plt.show()

# %% [markdown]
# ## N-Sum

# %%
#### With P learning ###
dt = 0.25 #ms

init_phase = 100 #ms
init_phase_steps = int(init_phase/dt) 
learn_phase = 80000 # ms
learn_phase_steps = int(learn_phase/dt) 
eval_phase = 100 # ms
eval_phase_steps = int(eval_phase/dt)

# init both teacher and student net
N, bit_time = 3, 4

n_in, n_hidden1, n_hidden2, n_hidden3, n_out = 1, 8, 6, 6, 2
beta=torch.tensor([0.1, 0.5])
activation='sigmoid'

student = DENetwork(
    layers=[
        FwdDENeurons(n_in=n_in, n_neurons=n_hidden1, tau = dt*np.logspace(0, 1.4, n_hidden1, dtype=np.float32), lr_w=1e1,
                     activation=activation, dt=dt, bias=True, scale=1.6),
        FwdDENeurons(n_in=n_hidden1, n_neurons=n_hidden2, tau = dt*np.logspace(0, 1.1, n_hidden2, dtype=np.float32), lr_w=2.5,
                     activation=activation, dt=dt, bias=True, scale=0.4),
        LastFwdDENeurons(n_in=n_hidden2, n_neurons=n_hidden3, tau = [3*dt, 0.4, 3.7, 4.1, 1., 2.], lr_w=0.5,
                     activation='sigmoid', dt=dt, bias=True, scale=1.6),
        FwdInsNeurons(n_in=n_hidden3, n_neurons=n_out, tau = dt, 
                   lr_w=0.1, activation='sigmoid', dt=dt, beta=beta, bias=True, scale=1.)
    ],)


student2 = FwdNetwork(net=student, layers=FwdEPNeurons)

student3 = FwdNetwork(net=student, layers=FwdGLENeurons)
student_naive = copy.deepcopy(student2)

Students={'DeepElig':student, 'Eprop':student2, 'GLE':student3, 'naive':student_naive}

input_fuc = StepSumBi(N=N, bit_time=bit_time, dt=dt)

#recorders
Rcd = Recorder(['input', 'teacher', 'student'])

with torch.no_grad():
    
    for t in range(init_phase_steps):
        input, label = input_fuc()
        r_out, u_out = student.step(input)
        Rcd.rec([input, label, r_out])
        
    error = label - r_out
    print("reach steady state with error: %f"%(error**2).mean().item())

Rcd.finish()

fig, axs = plt.subplots(n_out+1, 1, figsize=(10, 10), sharex=True)
x = np.arange(0, init_phase, dt)
axs[0].plot(x, Rcd['input'].mean(axis=0)*0.6, color=black, label='input', linewidth=2, alpha=0.8)
axs[0].plot(x, Rcd['teacher'][0], label="Sum", color = red, alpha=0.8, linewidth=3)
axs[0].plot(x, Rcd['teacher'][1], label="Sum", color = red, alpha=0.8, linewidth=3, linestyle='--')
for i in range(n_out):
    axs[i+1].plot(x, Rcd['student'][i], label="student %d"%i, color = lightblue)


axs[-1].set_xlabel("t (ms)")
axs[0].set_ylabel(r"$r_{in}$")
axs[0].legend()
axs[1].set_ylabel(r"$r_o$")

plt.show()
# Out:
# reach steady state with error: 0.228399

# %%
Cum_errors = np.array(3*[(error**2).mean().item()])
error_record, mismatch_record = [], []
cum_eps = 0
Students['Eprop'].align(student)
Students['GLE'].align(student)
Rcd = Recorder(['input','rhod'])
decay = torch.tensor([0.997, 0.998])

with torch.no_grad():
    for t in range(learn_phase_steps):
        t += init_phase_steps
        input, label = input_fuc()
        
        for i, stu in enumerate(['DeepElig', 'Eprop', 'GLE']):
            r_out, u_out = Students[stu].step(input)
            error = label - r_out
            Students[stu].prop(error)
            Students[stu].learnW()
            Cum_errors[i] = 0.999*Cum_errors[i] + 0.001*(error**2).mean().item()

        # Rcd.rec([input, student.mismatch(0), student.mismatch(-1), student.epsilon(1), 
        #          student.layers[0].rho.d, student3.mismatch(0)])

        if (t*dt)%200==0:
            error_record.append(list(Cum_errors))
            beta *= decay
            for i, stu in enumerate(['DeepElig', 'Eprop', 'GLE']):
                Students[stu].layers[-1].beta = beta
            
            print(" error: %5e, t: %d ms"%(Cum_errors[0], t*dt))

Rcd.finish()
# Out:
#  error: 2.356018e-01, t: 200 ms
#  error: 2.442779e-01, t: 400 ms
#  error: 2.457584e-01, t: 600 ms
#  error: 2.405576e-01, t: 800 ms
#  error: 2.417848e-01, t: 1000 ms
#  error: 2.395659e-01, t: 1200 ms
#  error: 2.354443e-01, t: 1400 ms
#  error: 2.385836e-01, t: 1600 ms
#  error: 2.295229e-01, t: 1800 ms
#  error: 2.232516e-01, t: 2000 ms
#  error: 2.218267e-01, t: 2200 ms
#  error: 2.239818e-01, t: 2400 ms
#  error: 2.079543e-01, t: 2600 ms
#  error: 2.183921e-01, t: 2800 ms
#  error: 2.221527e-01, t: 3000 ms
#  error: 2.290026e-01, t: 3200 ms
#  error: 2.243587e-01, t: 3400 ms
#  error: 2.257307e-01, t: 3600 ms
#  error: 2.291945e-01, t: 3800 ms
#  error: 2.296884e-01, t: 4000 ms
#  error: 2.315127e-01, t: 4200 ms
#  error: 2.212582e-01, t: 4400 ms
#  error: 2.134517e-01, t: 4600 ms
#  error: 2.122869e-01, t: 4800 ms
#  error: 2.101934e-01, t: 5000 ms
#  error: 2.139394e-01, t: 5200 ms
#  error: 2.102572e-01, t: 5400 ms
#  error: 2.110410e-01, t: 5600 ms
#  error: 2.062546e-01, t: 5800 ms
#  error: 1.982897e-01, t: 6000 ms
#  error: 2.047018e-01, t: 6200 ms
#  error: 1.844979e-01, t: 6400 ms
#  error: 1.812068e-01, t: 6600 ms
#  error: 1.895600e-01, t: 6800 ms
#  error: 1.924586e-01, t: 7000 ms
#  error: 1.914925e-01, t: 7200 ms
#  error: 1.960265e-01, t: 7400 ms
#  error: 1.862831e-01, t: 7600 ms
#  error: 1.869077e-01, t: 7800 ms
#  error: 1.832069e-01, t: 8000 ms
#  error: 1.979767e-01, t: 8200 ms
#  error: 1.883639e-01, t: 8400 ms
#  error: 1.931940e-01, t: 8600 ms
#  error: 1.944964e-01, t: 8800 ms
#  error: 1.936782e-01, t: 9000 ms
#  error: 1.848141e-01, t: 9200 ms
#  error: 1.754276e-01, t: 9400 ms
#  error: 1.900097e-01, t: 9600 ms
#  error: 1.930639e-01, t: 9800 ms
#  error: 1.909414e-01, t: 10000 ms
#  error: 1.872638e-01, t: 10200 ms
#  error: 1.849853e-01, t: 10400 ms
#  error: 1.782461e-01, t: 10600 ms
#  error: 1.856449e-01, t: 10800 ms
#  error: 1.809397e-01, t: 11000 ms
#  error: 1.865548e-01, t: 11200 ms
#  error: 1.821815e-01, t: 11400 ms
#  error: 1.803258e-01, t: 11600 ms
#  error: 1.697539e-01, t: 11800 ms
#  error: 1.798003e-01, t: 12000 ms
#  error: 1.954116e-01, t: 12200 ms
#  error: 1.921021e-01, t: 12400 ms
#  error: 1.854643e-01, t: 12600 ms
#  error: 1.706824e-01, t: 12800 ms
#  error: 1.756914e-01, t: 13000 ms
#  error: 1.699189e-01, t: 13200 ms
#  error: 1.614050e-01, t: 13400 ms
#  error: 1.664363e-01, t: 13600 ms
#  error: 1.738687e-01, t: 13800 ms
#  error: 1.712700e-01, t: 14000 ms
#  error: 1.568335e-01, t: 14200 ms
#  error: 1.568180e-01, t: 14400 ms
#  error: 1.611504e-01, t: 14600 ms
#  error: 1.671601e-01, t: 14800 ms
#  error: 1.579088e-01, t: 15000 ms
#  error: 1.665734e-01, t: 15200 ms
#  error: 1.675652e-01, t: 15400 ms
#  error: 1.577819e-01, t: 15600 ms
#  error: 1.724162e-01, t: 15800 ms
#  error: 1.626775e-01, t: 16000 ms
#  error: 1.664724e-01, t: 16200 ms
#  error: 1.698089e-01, t: 16400 ms
#  error: 1.525510e-01, t: 16600 ms
#  error: 1.597550e-01, t: 16800 ms
#  error: 1.530906e-01, t: 17000 ms
#  error: 1.606408e-01, t: 17200 ms
#  error: 1.573346e-01, t: 17400 ms
#  error: 1.676203e-01, t: 17600 ms
#  error: 1.524401e-01, t: 17800 ms
#  error: 1.594578e-01, t: 18000 ms
#  error: 1.649537e-01, t: 18200 ms
#  error: 1.463990e-01, t: 18400 ms
#  error: 1.476755e-01, t: 18600 ms
#  error: 1.586125e-01, t: 18800 ms
#  error: 1.639785e-01, t: 19000 ms
#  error: 1.573646e-01, t: 19200 ms
#  error: 1.650825e-01, t: 19400 ms
#  error: 1.592782e-01, t: 19600 ms
#  error: 1.457019e-01, t: 19800 ms
#  error: 1.350693e-01, t: 20000 ms
#  error: 1.553678e-01, t: 20200 ms
#  error: 1.505289e-01, t: 20400 ms
#  error: 1.565371e-01, t: 20600 ms
#  error: 1.340740e-01, t: 20800 ms
#  error: 1.410772e-01, t: 21000 ms
#  error: 1.572003e-01, t: 21200 ms
#  error: 1.484690e-01, t: 21400 ms
#  error: 1.393882e-01, t: 21600 ms
#  error: 1.370421e-01, t: 21800 ms
#  error: 1.240184e-01, t: 22000 ms
#  error: 1.272133e-01, t: 22200 ms
#  error: 1.304124e-01, t: 22400 ms
#  error: 1.348519e-01, t: 22600 ms
#  error: 1.280215e-01, t: 22800 ms
#  error: 1.404082e-01, t: 23000 ms
#  error: 1.325938e-01, t: 23200 ms
#  error: 1.320029e-01, t: 23400 ms
#  error: 1.524869e-01, t: 23600 ms
#  error: 1.442303e-01, t: 23800 ms
#  error: 1.274244e-01, t: 24000 ms
#  error: 1.366499e-01, t: 24200 ms
#  error: 1.237179e-01, t: 24400 ms
#  error: 1.311931e-01, t: 24600 ms
#  error: 1.248078e-01, t: 24800 ms
#  error: 1.401273e-01, t: 25000 ms
#  error: 1.295582e-01, t: 25200 ms
#  error: 1.236981e-01, t: 25400 ms
#  error: 1.052342e-01, t: 25600 ms
#  error: 1.231434e-01, t: 25800 ms
#  error: 1.277069e-01, t: 26000 ms
#  error: 1.264288e-01, t: 26200 ms
#  error: 1.222737e-01, t: 26400 ms
#  error: 1.297211e-01, t: 26600 ms
#  error: 1.253852e-01, t: 26800 ms
#  error: 1.171698e-01, t: 27000 ms
#  error: 1.058274e-01, t: 27200 ms
#  error: 1.193718e-01, t: 27400 ms
#  error: 1.083700e-01, t: 27600 ms
#  error: 1.176403e-01, t: 27800 ms
#  error: 1.167769e-01, t: 28000 ms
#  error: 1.272432e-01, t: 28200 ms
#  error: 1.286531e-01, t: 28400 ms
#  error: 1.166365e-01, t: 28600 ms
#  error: 1.145412e-01, t: 28800 ms
#  error: 1.106480e-01, t: 29000 ms
#  error: 1.227699e-01, t: 29200 ms
#  error: 1.106056e-01, t: 29400 ms
#  error: 9.507971e-02, t: 29600 ms
#  error: 1.091953e-01, t: 29800 ms
#  error: 9.451842e-02, t: 30000 ms
#  error: 9.390780e-02, t: 30200 ms
#  error: 1.042741e-01, t: 30400 ms
#  error: 9.076061e-02, t: 30600 ms
#  error: 9.699132e-02, t: 30800 ms
#  error: 9.280764e-02, t: 31000 ms
#  error: 9.120801e-02, t: 31200 ms
#  error: 9.875097e-02, t: 31400 ms
#  error: 1.019456e-01, t: 31600 ms
#  error: 8.886860e-02, t: 31800 ms
#  error: 9.284789e-02, t: 32000 ms
#  error: 9.976155e-02, t: 32200 ms
#  error: 9.567306e-02, t: 32400 ms
#  error: 9.355499e-02, t: 32600 ms
#  error: 8.098068e-02, t: 32800 ms
#  error: 9.163760e-02, t: 33000 ms
#  error: 8.852060e-02, t: 33200 ms
#  error: 1.023687e-01, t: 33400 ms
#  error: 1.035309e-01, t: 33600 ms
#  error: 1.063791e-01, t: 33800 ms
#  error: 9.110944e-02, t: 34000 ms
#  error: 9.014914e-02, t: 34200 ms
#  error: 9.046185e-02, t: 34400 ms
#  error: 8.167491e-02, t: 34600 ms
#  error: 8.409681e-02, t: 34800 ms
#  error: 8.993154e-02, t: 35000 ms
#  error: 9.408563e-02, t: 35200 ms
#  error: 9.272348e-02, t: 35400 ms
#  error: 9.573271e-02, t: 35600 ms
#  error: 8.842029e-02, t: 35800 ms
#  error: 8.271079e-02, t: 36000 ms
#  error: 9.383243e-02, t: 36200 ms
#  error: 1.030342e-01, t: 36400 ms
#  error: 8.977874e-02, t: 36600 ms
#  error: 7.944683e-02, t: 36800 ms
#  error: 8.702115e-02, t: 37000 ms
#  error: 9.443032e-02, t: 37200 ms
#  error: 8.594486e-02, t: 37400 ms
#  error: 1.011513e-01, t: 37600 ms
#  error: 9.797754e-02, t: 37800 ms
#  error: 1.011722e-01, t: 38000 ms
#  error: 9.577425e-02, t: 38200 ms
#  error: 9.332061e-02, t: 38400 ms
#  error: 9.153543e-02, t: 38600 ms
#  error: 7.968684e-02, t: 38800 ms
#  error: 7.341032e-02, t: 39000 ms
#  error: 7.048655e-02, t: 39200 ms
#  error: 8.353073e-02, t: 39400 ms
#  error: 7.969127e-02, t: 39600 ms
#  error: 7.524898e-02, t: 39800 ms
#  error: 8.243592e-02, t: 40000 ms
#  error: 8.226921e-02, t: 40200 ms
#  error: 7.529170e-02, t: 40400 ms
#  error: 7.134318e-02, t: 40600 ms
#  error: 7.227687e-02, t: 40800 ms
#  error: 7.726125e-02, t: 41000 ms
#  error: 8.784055e-02, t: 41200 ms
#  error: 8.738969e-02, t: 41400 ms
#  error: 8.276512e-02, t: 41600 ms
#  error: 8.356865e-02, t: 41800 ms
#  error: 8.046289e-02, t: 42000 ms
#  error: 7.072573e-02, t: 42200 ms
#  error: 6.435403e-02, t: 42400 ms
#  error: 6.539033e-02, t: 42600 ms
#  error: 7.101228e-02, t: 42800 ms
#  error: 5.905743e-02, t: 43000 ms
#  error: 6.459246e-02, t: 43200 ms
#  error: 6.799333e-02, t: 43400 ms
#  error: 7.253670e-02, t: 43600 ms
#  error: 6.284028e-02, t: 43800 ms
#  error: 6.074037e-02, t: 44000 ms
#  error: 7.196584e-02, t: 44200 ms
#  error: 7.605828e-02, t: 44400 ms
#  error: 6.857268e-02, t: 44600 ms
#  error: 6.489128e-02, t: 44800 ms
#  error: 5.662974e-02, t: 45000 ms
#  error: 6.338298e-02, t: 45200 ms
#  error: 7.250683e-02, t: 45400 ms
#  error: 7.143255e-02, t: 45600 ms
#  error: 7.085011e-02, t: 45800 ms
#  error: 7.023398e-02, t: 46000 ms
#  error: 6.329820e-02, t: 46200 ms
#  error: 6.081705e-02, t: 46400 ms
#  error: 6.671018e-02, t: 46600 ms
#  error: 6.894891e-02, t: 46800 ms
#  error: 6.942963e-02, t: 47000 ms
#  error: 6.690234e-02, t: 47200 ms
#  error: 7.184428e-02, t: 47400 ms
#  error: 7.231567e-02, t: 47600 ms
#  error: 6.977700e-02, t: 47800 ms
#  error: 6.985726e-02, t: 48000 ms
#  error: 6.443008e-02, t: 48200 ms
#  error: 6.546477e-02, t: 48400 ms
#  error: 6.357651e-02, t: 48600 ms
#  error: 6.305663e-02, t: 48800 ms
#  error: 5.997348e-02, t: 49000 ms
#  error: 5.317624e-02, t: 49200 ms
#  error: 5.574675e-02, t: 49400 ms
#  error: 5.986277e-02, t: 49600 ms
#  error: 6.290728e-02, t: 49800 ms
#  error: 6.477969e-02, t: 50000 ms
#  error: 5.754039e-02, t: 50200 ms
#  error: 5.582844e-02, t: 50400 ms
#  error: 5.667865e-02, t: 50600 ms
#  error: 6.244671e-02, t: 50800 ms
#  error: 5.574082e-02, t: 51000 ms
#  error: 6.255942e-02, t: 51200 ms
#  error: 6.168686e-02, t: 51400 ms
#  error: 5.602078e-02, t: 51600 ms
#  error: 5.389113e-02, t: 51800 ms
#  error: 5.929141e-02, t: 52000 ms
#  error: 5.135450e-02, t: 52200 ms
#  error: 5.643723e-02, t: 52400 ms
#  error: 5.099770e-02, t: 52600 ms
#  error: 5.256970e-02, t: 52800 ms
#  error: 5.228179e-02, t: 53000 ms
#  error: 5.848733e-02, t: 53200 ms
#  error: 5.531211e-02, t: 53400 ms
#  error: 5.407388e-02, t: 53600 ms
#  error: 5.398233e-02, t: 53800 ms
#  error: 5.012616e-02, t: 54000 ms
#  error: 4.831360e-02, t: 54200 ms
#  error: 5.132675e-02, t: 54400 ms
#  error: 4.823258e-02, t: 54600 ms
#  error: 5.040339e-02, t: 54800 ms
#  error: 5.305774e-02, t: 55000 ms
#  error: 4.678806e-02, t: 55200 ms
#  error: 5.249680e-02, t: 55400 ms
#  error: 4.794184e-02, t: 55600 ms
#  error: 4.873419e-02, t: 55800 ms
#  error: 4.712696e-02, t: 56000 ms
#  error: 4.941211e-02, t: 56200 ms
#  error: 4.512507e-02, t: 56400 ms
#  error: 4.799183e-02, t: 56600 ms
#  error: 4.832933e-02, t: 56800 ms
#  error: 4.766339e-02, t: 57000 ms
#  error: 4.800553e-02, t: 57200 ms
#  error: 4.760516e-02, t: 57400 ms
#  error: 5.148166e-02, t: 57600 ms
#  error: 4.632341e-02, t: 57800 ms
#  error: 5.214148e-02, t: 58000 ms
#  error: 5.349427e-02, t: 58200 ms
#  error: 5.136752e-02, t: 58400 ms
#  error: 4.912759e-02, t: 58600 ms
#  error: 4.794534e-02, t: 58800 ms
#  error: 4.450837e-02, t: 59000 ms
#  error: 5.049239e-02, t: 59200 ms
#  error: 4.233207e-02, t: 59400 ms
#  error: 3.303519e-02, t: 59600 ms
#  error: 4.070625e-02, t: 59800 ms
#  error: 4.067436e-02, t: 60000 ms
#  error: 4.841807e-02, t: 60200 ms
#  error: 4.746469e-02, t: 60400 ms
#  error: 4.183377e-02, t: 60600 ms
#  error: 4.761775e-02, t: 60800 ms
#  error: 4.507852e-02, t: 61000 ms
#  error: 4.298078e-02, t: 61200 ms
#  error: 4.390249e-02, t: 61400 ms
#  error: 4.339904e-02, t: 61600 ms
#  error: 4.579789e-02, t: 61800 ms
#  error: 4.036736e-02, t: 62000 ms
#  error: 4.290383e-02, t: 62200 ms
#  error: 4.207060e-02, t: 62400 ms
#  error: 4.261720e-02, t: 62600 ms
#  error: 4.164623e-02, t: 62800 ms
#  error: 4.489767e-02, t: 63000 ms
#  error: 4.217567e-02, t: 63200 ms
#  error: 4.248400e-02, t: 63400 ms
#  error: 4.024635e-02, t: 63600 ms
#  error: 4.461683e-02, t: 63800 ms
#  error: 4.628759e-02, t: 64000 ms
#  error: 4.319654e-02, t: 64200 ms
#  error: 4.489165e-02, t: 64400 ms
#  error: 3.483358e-02, t: 64600 ms
#  error: 3.710763e-02, t: 64800 ms
#  error: 4.060621e-02, t: 65000 ms
#  error: 4.212693e-02, t: 65200 ms
#  error: 4.354117e-02, t: 65400 ms
#  error: 4.137409e-02, t: 65600 ms
#  error: 4.192778e-02, t: 65800 ms
#  error: 4.271699e-02, t: 66000 ms
#  error: 4.297495e-02, t: 66200 ms
#  error: 4.675505e-02, t: 66400 ms
#  error: 4.125103e-02, t: 66600 ms
#  error: 4.017510e-02, t: 66800 ms
#  error: 4.331641e-02, t: 67000 ms
#  error: 3.892357e-02, t: 67200 ms
#  error: 3.943380e-02, t: 67400 ms
#  error: 4.361904e-02, t: 67600 ms
#  error: 4.425228e-02, t: 67800 ms
#  error: 4.802940e-02, t: 68000 ms
#  error: 4.694234e-02, t: 68200 ms
#  error: 4.405341e-02, t: 68400 ms
#  error: 4.126966e-02, t: 68600 ms
#  error: 4.093008e-02, t: 68800 ms
#  error: 4.203999e-02, t: 69000 ms
#  error: 3.760188e-02, t: 69200 ms
#  error: 4.235342e-02, t: 69400 ms
#  error: 4.038090e-02, t: 69600 ms
#  error: 4.265995e-02, t: 69800 ms
#  error: 4.225251e-02, t: 70000 ms
#  error: 4.311299e-02, t: 70200 ms
#  error: 4.124270e-02, t: 70400 ms
#  error: 3.986513e-02, t: 70600 ms
#  error: 4.262293e-02, t: 70800 ms
#  error: 4.424974e-02, t: 71000 ms
#  error: 4.671438e-02, t: 71200 ms
#  error: 4.484155e-02, t: 71400 ms
#  error: 4.229667e-02, t: 71600 ms
#  error: 4.157841e-02, t: 71800 ms
#  error: 4.078718e-02, t: 72000 ms
#  error: 4.196160e-02, t: 72200 ms
#  error: 3.539368e-02, t: 72400 ms
#  error: 3.801577e-02, t: 72600 ms
#  error: 3.794226e-02, t: 72800 ms
#  error: 3.871484e-02, t: 73000 ms
#  error: 4.028122e-02, t: 73200 ms
#  error: 3.847193e-02, t: 73400 ms
#  error: 3.959366e-02, t: 73600 ms
#  error: 4.069444e-02, t: 73800 ms
#  error: 3.920388e-02, t: 74000 ms
#  error: 3.821554e-02, t: 74200 ms
#  error: 3.902920e-02, t: 74400 ms
#  error: 4.066700e-02, t: 74600 ms
#  error: 3.887724e-02, t: 74800 ms
#  error: 4.309642e-02, t: 75000 ms
#  error: 4.210681e-02, t: 75200 ms
#  error: 4.064960e-02, t: 75400 ms
#  error: 4.126106e-02, t: 75600 ms
#  error: 4.310468e-02, t: 75800 ms
#  error: 3.743877e-02, t: 76000 ms
#  error: 3.927130e-02, t: 76200 ms
#  error: 4.011365e-02, t: 76400 ms
#  error: 3.534440e-02, t: 76600 ms
#  error: 3.897749e-02, t: 76800 ms
#  error: 4.218864e-02, t: 77000 ms
#  error: 4.023916e-02, t: 77200 ms
#  error: 4.056568e-02, t: 77400 ms
#  error: 3.555482e-02, t: 77600 ms
#  error: 3.459966e-02, t: 77800 ms
#  error: 3.628998e-02, t: 78000 ms
#  error: 3.775831e-02, t: 78200 ms
#  error: 3.723598e-02, t: 78400 ms
#  error: 3.864869e-02, t: 78600 ms
#  error: 3.911429e-02, t: 78800 ms
#  error: 3.623193e-02, t: 79000 ms
#  error: 3.428760e-02, t: 79200 ms
#  error: 3.878841e-02, t: 79400 ms
#  error: 3.788479e-02, t: 79600 ms
#  error: 3.348116e-02, t: 79800 ms
#  error: 3.719494e-02, t: 80000 ms

# %%
Error_record = np.array(error_record).T
fig = plt.figure(figsize=(10, 4))
time = np.arange(Error_record.shape[1])*200
ax = fig.add_subplot(111)
ax2 = ax.twinx()
ax.set_yscale('log')
ax.set_ylabel('loss', rotation=0)
ax2.set_yscale('log')
#ax2.set_ylabel(r"$\mathbf{u}^{ɑ}$", rotation=0)
l1,  = ax.plot(time, Error_record[0], label="DeepE", color=blue, linewidth=2.5, alpha=0.8)
l11, = ax.plot(time, Error_record[1], label="E-prop", color=green, linewidth=2.5, alpha=0.8)
l12, = ax.plot(time, Error_record[2], label="GLE", color=purple, linewidth=2.5, alpha=0.8)
lines = [l1, l11, l12]
labels = [line.get_label() for line in lines]
ax.legend(lines, labels, loc='upper right', frameon=False)
ax.set_xlabel('t (ms)')

plt.tight_layout()
#plt.savefig('./fig/losscurvecompare2L.png')
plt.show()

# %%
student.layers[-1].beta
# Out:
# tensor([0.0301, 0.2245])

# %%
Rcd_eval = Recorder(['input', 'teacher', 'DeepElig', 'Eprop', 'GLE', 'naive'])

#Students['naive'].align(student)
with torch.no_grad():
    for t in range(eval_phase_steps):
        t = t+init_phase_steps+learn_phase_steps
        input, label = input_fuc()
        Rcd_eval.rec_single('input', input)
        Rcd_eval.rec_single('teacher', label)
        for k, stu in Students.items():
            r_out, u_out = stu.step(input)
            Rcd_eval.rec_single(k, r_out)

Rcd_eval.finish()



fig, axs = plt.subplots(3, 1, figsize=(10, 6), sharex=True)
x = np.arange(0, eval_phase, dt)
axs[0].plot(x, Rcd_eval['input'].mean(axis=0), color=black, label='input', linewidth=2, alpha=0.8)


    
for i in range(n_out):
    axs[i+1].plot(x, Rcd_eval['teacher'][i], label="Sum", color=darkred, alpha=0.3, linewidth=4)
    #axs[i+1].plot(x, Rcd_eval['naive'][i][:], label="naive", color = lightblue, linewidth=2)
    axs[i+1].plot(x, Rcd_eval['DeepElig'][i][:], label="DeepElig", color = blue, linewidth=2)
    axs[i+1].plot(x, Rcd_eval['Eprop'][i][:], label="Eprop", color = green, linewidth=2)
    axs[i+1].plot(x, Rcd_eval['GLE'][i][:], label="GLE", color = purple, linewidth=2)
    
axs[0].legend()
axs[1].legend()
axs[-1].set_xlabel("t (ms)")

axs[0].set_ylabel(r"$r_{in}$")
axs[1].set_ylabel(r"$r_{sum}$")

for ax in axs:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

plt.tight_layout()
#plt.savefig('./fig/CompareAftRec.png')
plt.show()

# %% [markdown]
# # MNIST-1D

# %%
from mnist1d.data import make_dataset, get_dataset_args, get_templates
from mnist1d.utils import from_pickle, to_pickle, ObjectView, set_seed, plot_signals

arg_dict = ObjectView({
    'num_samples': 5000,
    'train_split': 0.8,
    'template_len': 12,
    'padding': [36,60],
    'scale_coeff': .4, 
    'max_translation': 48,
    'corr_noise_scale': 0.25,
    'iid_noise_scale': 2e-2,
    'shear_scale': 0.75,
    'shuffle_seq': False,
    'final_seq_length': 72,
    'seed': 42,
    'url': 'https://github.com/greydanus/mnist1d/raw/master/mnist1d_data.pkl'
})
data = make_dataset(arg_dict)

templates = get_templates()
print("Templates for the MNIST-1D dataset:")
x = templates['x']
t = templates['t']
y = templates['y']
fig = plot_signals(x, t, labels=y, args=arg_dict, ratio=1.33, dark_mode=True, do_transform=True)
# Out:
# Templates for the MNIST-1D dataset:

# %%
print(data.keys())
x, y, t = torch.tensor(data['x'],dtype=torch.float32).unsqueeze(-1), torch.tensor(data['y']), torch.tensor(data['t'])
x.shape, y.shape, t.shape
# Out:
# dict_keys(['x', 'x_test', 'y', 'y_test', 't', 'templates'])
# (torch.Size([4000, 72, 1]), torch.Size([4000]), torch.Size([72]))

# %%
#### With P learning ###
dt = 0.25 #ms
n_steps = arg_dict.final_seq_length

# init both teacher and student net
n_in, n_hidden1, n_hidden2, n_hidden3, n_hidden_ins, n_out = 1, 20, 24, 24, 40, 10
beta=0.3
activation='sigmoid'
Tau2 = torch.tensor([1.2, 2., 3.]*8)
Tau3 = torch.tensor([1.5, 2.4, 3.2]*8)

student = DENetwork(
    layers=[
        FwdDENeurons(n_in=n_in, n_neurons=n_hidden1, tau = dt+np.logspace(0, 1., n_hidden1, dtype=np.float32),
                     lr_w=2e1, activation=activation, dt=dt, scale=1.6),
        FwdDENeurons(n_in=n_hidden1, n_neurons=n_hidden2, tau = Tau2,
                     lr_w=5., activation=activation, dt=dt, scale=0.4),
        LastFwdDENeurons(n_in=n_hidden2, n_neurons=n_hidden3, tau = Tau3,
                         lr_w=1., activation=activation, dt=dt, scale=1.6),
        FwdInsNeurons(n_in=n_hidden3, n_neurons=n_hidden_ins, tau = dt, lr_w=0.1,
                      activation=activation, dt=dt, beta=beta, scale=1.),
        FwdInsNeurons(n_in=n_hidden_ins, n_neurons=n_out, tau = dt, lr_w=0.01, 
                      activation='linear', dt=dt, beta=beta, scale=1.)
    ],)

# %%
error_record, mismatch_record = [], []
decay = 1-2e-2
Cum_errors = 4
num_epochs = 30
with torch.no_grad():
    for epoch in range(num_epochs):
        permu = np.random.permutation(4000)
        for i, idx in enumerate(permu):
            total_error = 0.
            one_hot_label = torch.zeros(10)   
            one_hot_label[y[idx]] = 1.
            sample = x[idx]
            for t in range(n_steps):
                r_out, u_out = student.step(sample[t])
                if t>70:
                    p = torch.softmax(r_out, dim=0)
                    error = one_hot_label - p
                    student.prop(error)
                    student.learnW()
                    total_error += -(one_hot_label * torch.log(p)).sum().item()
                else:
                    student.prop(0)
            student.reset()
            Cum_errors = 0.98*Cum_errors + 0.02*total_error
        
            if i%500==0:
                error_record.append(Cum_errors)
                beta *= decay
                student.layers[-1].beta = beta       
                print(" error: %5e, iteration: %d samples"%(Cum_errors, i))
# Out:
#  error: 4.010648e+00, iteration: 0 samples
#  error: 2.050845e+00, iteration: 500 samples
#  error: 2.030220e+00, iteration: 1000 samples
#  error: 2.003660e+00, iteration: 1500 samples
#  error: 1.865571e+00, iteration: 2000 samples
#  error: 1.834659e+00, iteration: 2500 samples
#  error: 1.882859e+00, iteration: 3000 samples
#  error: 1.844164e+00, iteration: 3500 samples
#  error: 1.664227e+00, iteration: 0 samples
#  error: 1.836019e+00, iteration: 500 samples
#  error: 1.843303e+00, iteration: 1000 samples
#  error: 1.971985e+00, iteration: 1500 samples
#  error: 1.753740e+00, iteration: 2000 samples
#  error: 1.764326e+00, iteration: 2500 samples
#  error: 1.778142e+00, iteration: 3000 samples
#  error: 1.689035e+00, iteration: 3500 samples
#  error: 1.788640e+00, iteration: 0 samples
#  error: 1.746802e+00, iteration: 500 samples
#  error: 1.687120e+00, iteration: 1000 samples
#  error: 1.760686e+00, iteration: 1500 samples
#  error: 1.739166e+00, iteration: 2000 samples
#  error: 1.696125e+00, iteration: 2500 samples
#  error: 1.756158e+00, iteration: 3000 samples
#  error: 1.805443e+00, iteration: 3500 samples
#  error: 1.673514e+00, iteration: 0 samples
#  error: 1.708309e+00, iteration: 500 samples
#  error: 1.607753e+00, iteration: 1000 samples
#  error: 1.828079e+00, iteration: 1500 samples
#  error: 1.737991e+00, iteration: 2000 samples
#  error: 1.828790e+00, iteration: 2500 samples
#  error: 1.605348e+00, iteration: 3000 samples
#  error: 1.683045e+00, iteration: 3500 samples
#  error: 1.745282e+00, iteration: 0 samples
#  error: 1.630246e+00, iteration: 500 samples
#  error: 1.762202e+00, iteration: 1000 samples
#  error: 1.680253e+00, iteration: 1500 samples
#  error: 1.699901e+00, iteration: 2000 samples
#  error: 1.642353e+00, iteration: 2500 samples
#  error: 1.780470e+00, iteration: 3000 samples
#  error: 1.700059e+00, iteration: 3500 samples
#  error: 1.761543e+00, iteration: 0 samples
#  error: 1.720722e+00, iteration: 500 samples
#  error: 1.555832e+00, iteration: 1000 samples
#  error: 1.904186e+00, iteration: 1500 samples
#  error: 1.707684e+00, iteration: 2000 samples
#  error: 1.554272e+00, iteration: 2500 samples
#  error: 1.742243e+00, iteration: 3000 samples
#  error: 1.734164e+00, iteration: 3500 samples
#  error: 1.581458e+00, iteration: 0 samples
#  error: 1.634110e+00, iteration: 500 samples
#  error: 1.769451e+00, iteration: 1000 samples
#  error: 1.685825e+00, iteration: 1500 samples
#  error: 1.578219e+00, iteration: 2000 samples
#  error: 1.518579e+00, iteration: 2500 samples
#  error: 1.812500e+00, iteration: 3000 samples
#  error: 1.711555e+00, iteration: 3500 samples
#  error: 1.602052e+00, iteration: 0 samples
#  error: 1.543562e+00, iteration: 500 samples
#  error: 1.837922e+00, iteration: 1000 samples
#  error: 1.699330e+00, iteration: 1500 samples
#  error: 1.635989e+00, iteration: 2000 samples
#  error: 1.735213e+00, iteration: 2500 samples
#  error: 1.655179e+00, iteration: 3000 samples
#  error: 1.808785e+00, iteration: 3500 samples
#  error: 1.698426e+00, iteration: 0 samples
#  error: 1.759730e+00, iteration: 500 samples
#  error: 1.621865e+00, iteration: 1000 samples
#  error: 1.728013e+00, iteration: 1500 samples
#  error: 1.599350e+00, iteration: 2000 samples
#  error: 1.597869e+00, iteration: 2500 samples
#  error: 1.595987e+00, iteration: 3000 samples
#  error: 1.725108e+00, iteration: 3500 samples
#  error: 1.686998e+00, iteration: 0 samples
#  error: 1.565608e+00, iteration: 500 samples
#  error: 1.684880e+00, iteration: 1000 samples
#  error: 1.683353e+00, iteration: 1500 samples
#  error: 1.613250e+00, iteration: 2000 samples
#  error: 1.770100e+00, iteration: 2500 samples
#  error: 1.677908e+00, iteration: 3000 samples
#  error: 1.734948e+00, iteration: 3500 samples
#  error: 1.623515e+00, iteration: 0 samples
#  error: 1.727738e+00, iteration: 500 samples
#  error: 1.633900e+00, iteration: 1000 samples
#  error: 1.526363e+00, iteration: 1500 samples
#  error: 1.722812e+00, iteration: 2000 samples
#  error: 1.710544e+00, iteration: 2500 samples
#  error: 1.630613e+00, iteration: 3000 samples
#  error: 1.415753e+00, iteration: 3500 samples
#  error: 1.746555e+00, iteration: 0 samples
#  error: 1.640932e+00, iteration: 500 samples
#  error: 1.485237e+00, iteration: 1000 samples
#  error: 1.691415e+00, iteration: 1500 samples
#  error: 1.569866e+00, iteration: 2000 samples
#  error: 1.621669e+00, iteration: 2500 samples
#  error: 1.693641e+00, iteration: 3000 samples
#  error: 1.632642e+00, iteration: 3500 samples
#  error: 1.648872e+00, iteration: 0 samples
#  error: 1.646975e+00, iteration: 500 samples
#  error: 1.439109e+00, iteration: 1000 samples
#  error: 1.591962e+00, iteration: 1500 samples
#  error: 1.689680e+00, iteration: 2000 samples
#  error: 1.600828e+00, iteration: 2500 samples
#  error: 1.550748e+00, iteration: 3000 samples
#  error: 1.703390e+00, iteration: 3500 samples
#  error: 1.672172e+00, iteration: 0 samples
#  error: 1.659788e+00, iteration: 500 samples
#  error: 1.574895e+00, iteration: 1000 samples
#  error: 1.627250e+00, iteration: 1500 samples
#  error: 1.722654e+00, iteration: 2000 samples
#  error: 1.603688e+00, iteration: 2500 samples
#  error: 1.671507e+00, iteration: 3000 samples
#  error: 1.552709e+00, iteration: 3500 samples
#  error: 1.620103e+00, iteration: 0 samples
#  error: 1.682770e+00, iteration: 500 samples
#  error: 1.602676e+00, iteration: 1000 samples
#  error: 1.567921e+00, iteration: 1500 samples
#  error: 1.697901e+00, iteration: 2000 samples
#  error: 1.512798e+00, iteration: 2500 samples
#  error: 1.794117e+00, iteration: 3000 samples
#  error: 1.544408e+00, iteration: 3500 samples
#  error: 1.686147e+00, iteration: 0 samples
#  error: 1.759854e+00, iteration: 500 samples
#  error: 1.691318e+00, iteration: 1000 samples
#  error: 1.669791e+00, iteration: 1500 samples
#  error: 1.681340e+00, iteration: 2000 samples
#  error: 1.471971e+00, iteration: 2500 samples
#  error: 1.641005e+00, iteration: 3000 samples
#  error: 1.738687e+00, iteration: 3500 samples
#  error: 1.546789e+00, iteration: 0 samples
#  error: 1.838714e+00, iteration: 500 samples
#  error: 1.507375e+00, iteration: 1000 samples
#  error: 1.594202e+00, iteration: 1500 samples
#  error: 1.604536e+00, iteration: 2000 samples
#  error: 1.590442e+00, iteration: 2500 samples
#  error: 1.770763e+00, iteration: 3000 samples
#  error: 1.652109e+00, iteration: 3500 samples
#  error: 1.695974e+00, iteration: 0 samples
#  error: 1.588051e+00, iteration: 500 samples
#  error: 1.542304e+00, iteration: 1000 samples
#  error: 1.585215e+00, iteration: 1500 samples
#  error: 1.653888e+00, iteration: 2000 samples
#  error: 1.580630e+00, iteration: 2500 samples
#  error: 1.616196e+00, iteration: 3000 samples
#  error: 1.691518e+00, iteration: 3500 samples
#  error: 1.511145e+00, iteration: 0 samples
#  error: 1.692386e+00, iteration: 500 samples
#  error: 1.619197e+00, iteration: 1000 samples
#  error: 1.650396e+00, iteration: 1500 samples
#  error: 1.636919e+00, iteration: 2000 samples
#  error: 1.664700e+00, iteration: 2500 samples
#  error: 1.583178e+00, iteration: 3000 samples
#  error: 1.658962e+00, iteration: 3500 samples
#  error: 1.654167e+00, iteration: 0 samples
#  error: 1.690771e+00, iteration: 500 samples
#  error: 1.684983e+00, iteration: 1000 samples
#  error: 1.527570e+00, iteration: 1500 samples
#  error: 1.838432e+00, iteration: 2000 samples
#  error: 1.585356e+00, iteration: 2500 samples
#  error: 1.542018e+00, iteration: 3000 samples
#  error: 1.601475e+00, iteration: 3500 samples
#  error: 1.671606e+00, iteration: 0 samples
#  error: 1.687419e+00, iteration: 500 samples
#  error: 1.762578e+00, iteration: 1000 samples
#  error: 1.615263e+00, iteration: 1500 samples
#  error: 1.565968e+00, iteration: 2000 samples
#  error: 1.623967e+00, iteration: 2500 samples
#  error: 1.597662e+00, iteration: 3000 samples
#  error: 1.723807e+00, iteration: 3500 samples
#  error: 1.526603e+00, iteration: 0 samples
#  error: 1.622391e+00, iteration: 500 samples
#  error: 1.668217e+00, iteration: 1000 samples
#  error: 1.739490e+00, iteration: 1500 samples
#  error: 1.561631e+00, iteration: 2000 samples
#  error: 1.628149e+00, iteration: 2500 samples
#  error: 1.627625e+00, iteration: 3000 samples
#  error: 1.774343e+00, iteration: 3500 samples
#  error: 1.628290e+00, iteration: 0 samples
#  error: 1.699680e+00, iteration: 500 samples
#  error: 1.572274e+00, iteration: 1000 samples
#  error: 1.625279e+00, iteration: 1500 samples
#  error: 1.596605e+00, iteration: 2000 samples
#  error: 1.645348e+00, iteration: 2500 samples
#  error: 1.668054e+00, iteration: 3000 samples
#  error: 1.721630e+00, iteration: 3500 samples
#  error: 1.739932e+00, iteration: 0 samples
#  error: 1.621368e+00, iteration: 500 samples
#  error: 1.680152e+00, iteration: 1000 samples
#  error: 1.693583e+00, iteration: 1500 samples
#  error: 1.615199e+00, iteration: 2000 samples
#  error: 1.599588e+00, iteration: 2500 samples
#  error: 1.713528e+00, iteration: 3000 samples
#  error: 1.484529e+00, iteration: 3500 samples
#  error: 1.492896e+00, iteration: 0 samples
#  error: 1.435306e+00, iteration: 500 samples
#  error: 1.622639e+00, iteration: 1000 samples
#  error: 1.693690e+00, iteration: 1500 samples
#  error: 1.717174e+00, iteration: 2000 samples
#  error: 1.660571e+00, iteration: 2500 samples
#  error: 1.498580e+00, iteration: 3000 samples
#  error: 1.708174e+00, iteration: 3500 samples
#  error: 1.671409e+00, iteration: 0 samples
#  error: 1.642587e+00, iteration: 500 samples
#  error: 1.639349e+00, iteration: 1000 samples
#  error: 1.619170e+00, iteration: 1500 samples
#  error: 1.642333e+00, iteration: 2000 samples
#  error: 1.617244e+00, iteration: 2500 samples
#  error: 1.787108e+00, iteration: 3000 samples
#  error: 1.544418e+00, iteration: 3500 samples
#  error: 1.441625e+00, iteration: 0 samples
#  error: 1.599375e+00, iteration: 500 samples
#  error: 1.689819e+00, iteration: 1000 samples
#  error: 1.646649e+00, iteration: 1500 samples
#  error: 1.547870e+00, iteration: 2000 samples
#  error: 1.637119e+00, iteration: 2500 samples
#  error: 1.661455e+00, iteration: 3000 samples
#  error: 1.647335e+00, iteration: 3500 samples
#  error: 1.670503e+00, iteration: 0 samples
#  error: 1.526167e+00, iteration: 500 samples
#  error: 1.707016e+00, iteration: 1000 samples
#  error: 1.605257e+00, iteration: 1500 samples
#  error: 1.605276e+00, iteration: 2000 samples
#  error: 1.597838e+00, iteration: 2500 samples
#  error: 1.609961e+00, iteration: 3000 samples
#  error: 1.632813e+00, iteration: 3500 samples
#  error: 1.491407e+00, iteration: 0 samples
#  error: 1.547516e+00, iteration: 500 samples
#  error: 1.596498e+00, iteration: 1000 samples
#  error: 1.578058e+00, iteration: 1500 samples
#  error: 1.552308e+00, iteration: 2000 samples
#  error: 1.588571e+00, iteration: 2500 samples
#  error: 1.503415e+00, iteration: 3000 samples
#  error: 1.574417e+00, iteration: 3500 samples
#  error: 1.439831e+00, iteration: 0 samples
#  error: 1.611866e+00, iteration: 500 samples
#  error: 1.614586e+00, iteration: 1000 samples
#  error: 1.534477e+00, iteration: 1500 samples
#  error: 1.621513e+00, iteration: 2000 samples
#  error: 1.682104e+00, iteration: 2500 samples
#  error: 1.738473e+00, iteration: 3000 samples
#  error: 1.538550e+00, iteration: 3500 samples

# %%
student.layers[-1].beta
# Out:
# 0.17745759368913536

# %%
#TEST
x, y = torch.tensor(data['x_test'],dtype=torch.float32).unsqueeze(-1), torch.tensor(data['y_test'])
prediction = []
Cum_errors = 0.
with torch.no_grad():
    for idx in range(1000):
        total_error = 0.
        sample = x[idx]
        for t in range(n_steps):
            r_out, u_out = student.step(sample[t])
        prediction.append(torch.argmax(r_out).item())
        student.reset()
prediction= torch.tensor(prediction)
print('Accuracy: ', ((prediction==y)*1.).mean())
# Out:
# Accuracy:  tensor(0.3700)
