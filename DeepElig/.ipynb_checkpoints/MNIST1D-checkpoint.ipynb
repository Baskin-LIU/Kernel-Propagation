# %%
import numpy as np
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
import copy
from tqdm import tqdm
import sys
sys.path.insert(0, "../src/")
from FwdNeuron import *
from DeepEligNeuron import *
from Network import *
from inputFuc import *
from utils import *
from plotting import *
from utilsMNIST import *

# %%
def extract_kernel(model, n_steps, layer_idx):
    model.reset()
    impulse = torch.zeros(1, n_steps, 1)
    impulse[0] += 1
    kernel_record = []
    for t in range(n_steps):
        r = impulse[:, t]
        for l in model.layers[:layer_idx]:
            r,u = l.step(r)
        kernel_record.append(u.detach().clone())

    return torch.vstack(kernel_record)

# %% [markdown]
# # MNIST-1D

# %%
from mnist1d.data import make_dataset, get_dataset_args, get_templates
from mnist1d.utils import from_pickle, to_pickle, ObjectView, set_seed, plot_signals
###TODO padding###
data_config = default_data_config
general_config = default_general_config
train_config = default_train_config
model_config = default_model_config

data = make_dataset(ObjectView(data_config))

templates = get_templates()
print("Templates for the MNIST-1D dataset:")
x = templates['x']
t = templates['t']
y = templates['y']
fig = plot_signals(x, t, labels=y, args=ObjectView(data_config),
                   ratio=1.33, dark_mode=True, do_transform=True)
# Out:
# Templates for the MNIST-1D dataset:

# %%
print(data.keys())
x, y = torch.tensor(data['x'],dtype=torch.float32).unsqueeze(-1), torch.tensor(data['y'])
x_test, y_test = torch.tensor(data['x_test'],dtype=torch.float32).unsqueeze(-1), torch.tensor(data['y_test'])
x.shape, y.shape
# Out:
# dict_keys(['x', 'x_test', 'y', 'y_test', 't', 'templates'])
# (torch.Size([4000, 72, 1]), torch.Size([4000]))

# %%
#### With P learning ###
dt = general_config["dt"]
n_steps = data_config["final_seq_length"]
answer_period = 12

# init both teacher and student net
batch = train_config["batch_size"]

model = buildMNISTNet(model_config, general_config)

optimizer = torch.optim.Adam(
    model.parameters(),
    lr=4e-4#train_config["learning_rate"]
)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='min',
    factor=0.3,
    patience=2
)

kernel_record = extract_kernel(model, n_steps=int(1.5*data_config["final_seq_length"]), layer_idx=model_config["num_LP_layers"])
kernel_record_pre = kernel_record.numpy().T

# %%
error_record, mismatch_record = [], []
Cum_errors = 0.5
num_epochs = 50

with torch.no_grad():
    for epoch in range(num_epochs):
        permu = np.random.permutation(4000).reshape(-1, batch)
        pbar = tqdm(
            permu,
            total=permu.shape[0],
        )
        for idx in pbar:
            total_error = train_batch(model, optimizer, x[idx], y[idx], answer_period)
            Cum_errors = 0.95*Cum_errors + 0.05*total_error
                
        test_acc, test_loss = test(model, x_test, y_test, answer_period)
        scheduler.step(test_loss)
        error_record.append(Cum_errors)   
        print("Train loss: %3f, Test acc: %2f, Epoch: %d"%(Cum_errors, test_acc, epoch+1))
                
print('finished')
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.38it/s]
# Train loss: 0.173483, Test acc: 0.337000, Epoch: 1
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.34it/s]
# Train loss: 0.154992, Test acc: 0.382000, Epoch: 2
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.33it/s]
# Train loss: 0.144898, Test acc: 0.389000, Epoch: 3
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:11<00:00,  9.07it/s]
# Train loss: 0.146257, Test acc: 0.370000, Epoch: 4
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.31it/s]
# Train loss: 0.141431, Test acc: 0.408000, Epoch: 5
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.30it/s]
# Train loss: 0.141011, Test acc: 0.415000, Epoch: 6
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.27it/s]
# Train loss: 0.133186, Test acc: 0.412000, Epoch: 7
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.28it/s]
# Train loss: 0.136442, Test acc: 0.441000, Epoch: 8
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.25it/s]
# Train loss: 0.139017, Test acc: 0.440000, Epoch: 9
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.15it/s]
# Train loss: 0.133743, Test acc: 0.442000, Epoch: 10
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.26it/s]
# Train loss: 0.136995, Test acc: 0.416000, Epoch: 11
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.28it/s]
# Train loss: 0.129978, Test acc: 0.441000, Epoch: 12
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.30it/s]
# Train loss: 0.132065, Test acc: 0.473000, Epoch: 13
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.27it/s]
# Train loss: 0.131700, Test acc: 0.449000, Epoch: 14
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.29it/s]
# Train loss: 0.133710, Test acc: 0.457000, Epoch: 15
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.31it/s]
# Train loss: 0.128575, Test acc: 0.451000, Epoch: 16
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.27it/s]
# Train loss: 0.125539, Test acc: 0.483000, Epoch: 17
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.15it/s]
# Train loss: 0.123268, Test acc: 0.449000, Epoch: 18
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.25it/s]
# Train loss: 0.125205, Test acc: 0.472000, Epoch: 19
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.30it/s]
# Train loss: 0.125229, Test acc: 0.485000, Epoch: 20
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.31it/s]
# Train loss: 0.127126, Test acc: 0.489000, Epoch: 21
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.27it/s]
# Train loss: 0.123912, Test acc: 0.467000, Epoch: 22
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.18it/s]
# Train loss: 0.118834, Test acc: 0.477000, Epoch: 23
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.16it/s]
# Train loss: 0.125184, Test acc: 0.475000, Epoch: 24
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.22it/s]
# Train loss: 0.121722, Test acc: 0.476000, Epoch: 25
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.24it/s]
# Train loss: 0.119215, Test acc: 0.499000, Epoch: 26
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.22it/s]
# Train loss: 0.120337, Test acc: 0.491000, Epoch: 27
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:11<00:00,  9.03it/s]
# Train loss: 0.119427, Test acc: 0.467000, Epoch: 28
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.16it/s]
# Train loss: 0.122754, Test acc: 0.473000, Epoch: 29
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.19it/s]
# Train loss: 0.118171, Test acc: 0.514000, Epoch: 30
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.16it/s]
# Train loss: 0.113662, Test acc: 0.507000, Epoch: 31
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.17it/s]
# Train loss: 0.117157, Test acc: 0.508000, Epoch: 32
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:11<00:00,  9.02it/s]
# Train loss: 0.116899, Test acc: 0.514000, Epoch: 33
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.16it/s]
# Train loss: 0.114980, Test acc: 0.506000, Epoch: 34
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.18it/s]
# Train loss: 0.114978, Test acc: 0.515000, Epoch: 35
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.14it/s]
# Train loss: 0.112951, Test acc: 0.524000, Epoch: 36
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.21it/s]
# Train loss: 0.113305, Test acc: 0.522000, Epoch: 37
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:11<00:00,  9.07it/s]
# Train loss: 0.114927, Test acc: 0.518000, Epoch: 38
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.15it/s]
# Train loss: 0.115823, Test acc: 0.517000, Epoch: 39
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.18it/s]
# Train loss: 0.112640, Test acc: 0.507000, Epoch: 40
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.16it/s]
# Train loss: 0.113396, Test acc: 0.513000, Epoch: 41
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.15it/s]
# Train loss: 0.113873, Test acc: 0.516000, Epoch: 42
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:11<00:00,  9.05it/s]
# Train loss: 0.113259, Test acc: 0.517000, Epoch: 43
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.13it/s]
# Train loss: 0.111738, Test acc: 0.513000, Epoch: 44
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.19it/s]
# Train loss: 0.111477, Test acc: 0.520000, Epoch: 45
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:11<00:00,  9.03it/s]
# Train loss: 0.111059, Test acc: 0.524000, Epoch: 46
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:11<00:00,  9.02it/s]
# Train loss: 0.110811, Test acc: 0.520000, Epoch: 47
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:11<00:00,  9.01it/s]
# Train loss: 0.108449, Test acc: 0.512000, Epoch: 48
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.16it/s]
# Train loss: 0.112701, Test acc: 0.520000, Epoch: 49
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:11<00:00,  9.09it/s]
# Train loss: 0.111260, Test acc: 0.527000, Epoch: 50
# finished

# %%
for l in model.layers[:3]:
    print(l.TauDE, l.decay_de)
    print(l.elig.shape, torch.abs(l.elig).mean())
    print(torch.abs(l.W_in).mean(), torch.abs(l.bias).mean())
    print()
# Out:
# tensor([1.3000, 8.2000, 1.2000, 8.1000, 1.1000, 8.0000]) tensor([0.6154, 0.9390, 0.5833, 0.9383, 0.5455, 0.9375])
# torch.Size([1, 6, 60, 1]) tensor(0.)
# tensor(0.1899, grad_fn=<MeanBackward0>) tensor(0.0907, grad_fn=<MeanBackward0>)
#
# tensor([1.3000, 8.2000, 1.2000, 8.1000]) tensor([0.6154, 0.9390, 0.5833, 0.9383])
# torch.Size([1, 4, 60, 60]) tensor(0.)
# tensor(0.1747, grad_fn=<MeanBackward0>) tensor(0.0888, grad_fn=<MeanBackward0>)
#
# tensor([1.3000, 8.2000]) tensor([0.6154, 0.9390])
# torch.Size([1, 2, 60, 60]) tensor(0.)
# tensor(0.1774, grad_fn=<MeanBackward0>) tensor(0.0754, grad_fn=<MeanBackward0>)

# %%
for l in model.layers[:3]:
    print(l.TauDE, l.decay_de)
    print(l.elig.shape, torch.abs(l.elig).mean())
    print(torch.abs(l.W_in).mean(), torch.abs(l.bias).mean())
    print()
# Out:
# tensor([1.3000, 8.2000, 1.2000, 8.1000, 1.1000, 8.0000]) tensor([0.6154, 0.9390, 0.5833, 0.9383, 0.5455, 0.9375])
# torch.Size([40, 6, 60, 1]) tensor(0.2622)
# tensor(0.1848, grad_fn=<MeanBackward0>) tensor(0.0418, grad_fn=<MeanBackward0>)
#
# tensor([1.3000, 8.2000, 1.2000, 8.1000]) tensor([0.6154, 0.9390, 0.5833, 0.9383])
# torch.Size([40, 4, 60, 60]) tensor(0.0325)
# tensor(0.1705, grad_fn=<MeanBackward0>) tensor(0.0719, grad_fn=<MeanBackward0>)
#
# tensor([1.3000, 8.2000]) tensor([0.6154, 0.9390])
# torch.Size([40, 2, 60, 60]) tensor(0.0248)
# tensor(0.1714, grad_fn=<MeanBackward0>) tensor(0.0639, grad_fn=<MeanBackward0>)

# %%
#TEST
acc, loss = test(model, x_test, y_test, 1.5*answer_period)
print('Test Accuracy: ', acc, "Test Loss", loss)
# Out:
# Test Accuracy:  0.5049999952316284 Test Loss 0.12194836139678955

# %%
kernel_record = extract_kernel(model, n_steps=int(1.5*data_config["final_seq_length"]), layer_idx=model_config["num_LP_layers"])
kernel_record_post = kernel_record.numpy().T

# %%
kernel_record_pre_norm = kernel_record_pre / kernel_record_pre.mean(axis=1)[:, None]
kernel_record_post_norm = kernel_record_post / kernel_record_post.mean(axis=1)[:, None]
fig, axs = plt.subplots(10, 9, figsize=(16, 14))
for i, ax in enumerate(axs.ravel()):
    ax.plot(kernel_record_pre_norm[i])
    ax.plot(kernel_record_post_norm[i])

# %%
model.layers[0].W_in.min()
# Out:
# tensor(-5.9174, grad_fn=<MinBackward1>)
