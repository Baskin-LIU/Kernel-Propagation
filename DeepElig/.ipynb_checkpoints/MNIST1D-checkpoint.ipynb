# %%
import numpy as np
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
import copy
from tqdm import tqdm
import sys
sys.path.insert(0, "../src/")
from FwdNeuron import *
from DeepEligNeuron import *
from Network import *
from inputFuc import *
from utils import *
from plotting import *
from utilsMNIST import *

# %% [markdown]
# # MNIST-1D

# %%
from mnist1d.data import make_dataset, get_dataset_args, get_templates
from mnist1d.utils import from_pickle, to_pickle, ObjectView, set_seed, plot_signals
###TODO padding###
data_config = default_data_config
general_config = default_general_config
train_config = default_train_config
model_config = default_model_config

data = make_dataset(ObjectView(data_config))

templates = get_templates()
print("Templates for the MNIST-1D dataset:")
x = templates['x']
t = templates['t']
y = templates['y']
fig = plot_signals(x, t, labels=y, args=ObjectView(data_config),
                   ratio=1.33, dark_mode=True, do_transform=True)
# Out:
# Templates for the MNIST-1D dataset:

# %%
print(data.keys())
x, y = torch.tensor(data['x'],dtype=torch.float32).unsqueeze(-1), torch.tensor(data['y'])
x_test, y_test = torch.tensor(data['x_test'],dtype=torch.float32).unsqueeze(-1), torch.tensor(data['y_test'])
x.shape, y.shape
# Out:
# dict_keys(['x', 'x_test', 'y', 'y_test', 't', 'templates'])
# (torch.Size([4000, 144, 1]), torch.Size([4000]))

# %%
#### With P learning ###
dt = general_config["dt"]
n_steps = data_config["final_seq_length"]
answer_period = 6

# init both teacher and student net
batch = train_config["batch_size"]

model = buildMNISTNet(model_config, general_config)

optimizer = torch.optim.Adam(
    model.parameters(),
    lr=5e-4#train_config["learning_rate"]
)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='min',
    factor=0.1,
    patience=5
)

# %%
error_record, mismatch_record = [], []
Cum_errors = 0.5
num_epochs = 30

with torch.no_grad():
    for epoch in range(num_epochs):
        permu = np.random.permutation(4000).reshape(-1, batch)
        pbar = tqdm(
            permu,
            total=permu.shape[0],
        )
        #for i, idx in enumerate(permu):
        for idx in pbar:
            total_error = 0.
            one_hot_label = F.one_hot(y[idx], num_classes=10)
            sample = x[idx]
            model.reset()
            for t in range(n_steps):
                r_out, u_out = model.step(sample[:, t])
                if n_steps-t <= answer_period:
                    p = torch.softmax(r_out, dim=1)
                    error = (one_hot_label - p)/answer_period
                    model.prop(error)
                    model.backwards()
                    optimizer.step()
                    optimizer.zero_grad()
                    total_error += -(one_hot_label * torch.log(p)).mean().item()
                else:
                    model.prop(0)
            
            Cum_errors = 0.98*Cum_errors + 0.02*total_error/answer_period
                
        test_acc, test_loss = test(model, x_test, y_test, answer_period)
        scheduler.step(test_loss)
        error_record.append(Cum_errors)   
        print("Train loss: %3e, Test acc: %2e, Epoch: %d"%(Cum_errors, test_acc, epoch+1))
                
print('finished')
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:18<00:00,  5.37it/s]
# Train loss: 2.186418e-01, Test acc: 2.900000e-01, Epoch: 1
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:19<00:00,  5.21it/s]
# Train loss: 1.755541e-01, Test acc: 2.810000e-01, Epoch: 2
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:19<00:00,  5.26it/s]
# Train loss: 1.667514e-01, Test acc: 3.190000e-01, Epoch: 3
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:19<00:00,  5.17it/s]
# Train loss: 1.677575e-01, Test acc: 3.030000e-01, Epoch: 4
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:19<00:00,  5.15it/s]
# Train loss: 1.653998e-01, Test acc: 3.150000e-01, Epoch: 5
#  24%|███████████████████▋                                                              | 24/100 [00:04<00:15,  4.92it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 19
#      17 model.reset()
#      18 for t in range(n_steps):
# ---> 19     r_out, u_out = model.step(sample[:, t])
#      20     if n_steps-t <= answer_period:
#      21         p = torch.softmax(r_out, dim=1)
#
# File ~/Projects/DeepElig/KP/DeepElig/../src/Network.py:34, in FwdNetwork.step(self, r_in, noise)
#      32 r = r_in
#      33 for i, l in enumerate(self.layers):
# ---> 34     r, u = l.step(r_in=r, noise=noise)
#      36 return r, u
#
# File ~/Projects/DeepElig/KP/DeepElig/../src/DeepEligNeuron.py:10, in LastFwdDENeurons.step(self, r_in, noise, **kwargs)
#       9 def step(self, r_in, noise=0., **kwargs):
# ---> 10     self.step_bar(r_in, noise)
#      11     return self.r, self.u_bar
#
# File ~/Projects/DeepElig/KP/DeepElig/../src/FwdNeuron.py:106, in FwdNeurons.step_bar(self, r_in, noise, **kwargs)
#     104 def step_bar(self, r_in, noise=0., **kwargs):
#     105     self.r_bar = self.decay[None, :, None] * self.r_bar + self.dt_tau[None, :, None] * r_in[:, None, :]
# --> 106     self.u_bar = (self.r_bar*self.W_in).sum(-1) + self.bias
#     108     self.r = self.rho(self.u_bar)
#
# KeyboardInterrupt:

# %%
#TEST
acc, loss = test(model, x_test, y_test, answer_period)
print('Test Accuracy: ', acc, "Test Loss", loss)
# Out:
# Test Accuracy:  0.3619999885559082 Test Loss 0.15937970578670502
